# %%
import os
os.chdir(os.getcwd())

# %%
import pandas as pd

# %%
def predict_operons(filepath, threshold=50):
    # Read the PTT file into a dataframe
    df = pd.read_csv(filepath, skiprows=2, sep='\t')

    # Rename columns
    df.columns = ['Location', 'Strand', 'Length', 'PID', 'Gene', 'Synonym', 'Code', 'COG', 'Product']

    # Extract start and stop positions
    start = pd.Series([int(loc.split('..')[0]) for loc in df['Location']])
    stop = pd.Series([int(loc.split('..')[1]) for loc in df['Location']])
    df['Start'] = start
    df['Stop'] = stop

    # Sort by start position
    df = df.sort_values('Start')

    # Initialize variables
    operons_list = []
    operon = [df['Gene'].iloc[0]]
    prev_stop = df['Stop'].iloc[0]

    # Iterate through genes
    for i in range(1, len(df)):
        curr_start = df['Start'].iloc[i]
        curr_stop = df['Stop'].iloc[i]
        curr_gene = df['Gene'].iloc[i]

        # Check if current gene is in same operon as previous gene and thereby setting the difference to less than 50 as mentioned in the question
        if df['Strand'].iloc[i] == df['Strand'].iloc[i-1] and curr_start - prev_stop < threshold:
            operon.append(curr_gene)
        else:
            operons_list.append(operon)
            operon = [curr_gene]

        prev_stop = curr_stop
    operons_list.append(operon)

    # Return the number of operons and a brief list of the operons
    return (len(operons_list),operons_list)

# %%
predict_operons('E_coli_K12_MG1655.ptt')
# Out:
# (2669,
#  [['thrL'],
#   ['thrA', 'thrB', 'thrC'],
#   ['yaaX'],
#   ['yaaA'],
#   ['yaaJ'],
#   ['talB'],
#   ['mog'],
#   ['yaaH'],
#   ['yaaW', 'yaaI'],
#   ['dnaK'],
#   ['dnaJ'],
#   ['insL'],
#   ['hokC', 'mokC'],
#   ['nhaA'],
#   ['nhaR'],
#   ['insB', 'insA'],
#   ['rpsT'],
#   ['yaaY', 'ribF', 'ileS', 'lspA'],
#   ['fkpB', 'ispH'],
#   ['rihC'],
#   ['dapB'],
#   ['carA', 'carB'],
#   ['caiF'],
#   ['caiE', 'caiD'],
#   ['caiC'],
#   ['caiB'],
#   ['caiA', 'caiT'],
#   ['fixA', 'fixB'],
#   ['fixC', 'fixX'],
#   ['yaaU'],
#   ['kefF', 'kefC'],
#   ['folA'],
#   ['apaH', 'apaG', 'rsmA', 'pdxA', 'surA'],
#   ['lptD'],
#   ['djlA'],
#   ['rluA', 'rapA'],
#   ['polB'],
#   ['araD'],
#   ['araA', 'araB'],
#   ['araC'],
#   ['yabI'],
#   ['thiQ', 'thiP', 'thiB'],
#   ['sgrR'],
#   ['sgrT'],
#   ['setA'],
#   ['leuD', 'leuC', 'leuB', 'leuA'],
#   ['leuL'],
#   ['leuO'],
#   ['ilvI', 'ilvH'],
#   ['cra'],
#   ['mraZ',
#    'rsmH',
#    'ftsL',
#    'ftsI',
#    'murE',
#    'murF',
#    'mraY',
#    'murD',
#    'ftsW',
#    'murG'],
#   ['murC', 'ddlB', 'ftsQ', 'ftsA'],
#   ['ftsZ'],
#   ['lpxC'],
#   ['secM'],
#   ['secA'],
#   ['mutT'],
#   ['yacG', 'yacF', 'coaE'],
#   ['guaC'],
#   ['hofC', 'hofB', 'ppdD'],
#   ['nadC'],
#   ['ampD', 'ampE'],
#   ['aroP'],
#   ['pdhR'],
#   ['aceE', 'aceF'],
#   ['lpd'],
#   ['yacH'],
#   ['acnB'],
#   ['yacL'],
#   ['speD', 'speE'],
#   ['yacC'],
#   ['cueO'],
#   ['gcd'],
#   ['hpt'],
#   ['can'],
#   ['yadG', 'yadH'],
#   ['yadI'],
#   ['yadE'],
#   ['panD'],
#   ['yadD'],
#   ['panC', 'panB'],
#   ['yadC'],
#   ['yadK', 'yadL', 'yadM', 'htrE', 'ecpD'],
#   ['yadN'],
#   ['folK', 'pcnB'],
#   ['gluQ', 'dksA'],
#   ['sfsA', 'ligT'],
#   ['hrpB'],
#   ['mrcB'],
#   ['fhuA'],
#   ['fhuC', 'fhuD', 'fhuB'],
#   ['hemL'],
#   ['clcA'],
#   ['erpA'],
#   ['yadS', 'btuF', 'mtn'],
#   ['dgt'],
#   ['degP'],
#   ['cdaR'],
#   ['yaeH'],
#   ['yaeI'],
#   ['dapD', 'glnD'],
#   ['map'],
#   ['rpsB'],
#   ['tsf'],
#   ['pyrH'],
#   ['frr'],
#   ['dxr'],
#   ['ispU', 'cdsA', 'rseP', 'bamA'],
#   ['skp', 'lpxD'],
#   ['fabZ', 'lpxA', 'lpxB', 'rnhB', 'dnaE', 'accA'],
#   ['ldcC'],
#   ['yaeR'],
#   ['tilS'],
#   ['rof', 'yaeP'],
#   ['yaeQ', 'yaeJ', 'nlpE'],
#   ['yaeF'],
#   ['proS'],
#   ['yaeB', 'rcsF'],
#   ['metQ', 'metI', 'metN'],
#   ['gmhB'],
#   ['dkgB'],
#   ['yafC'],
#   ['yafD', 'yafE'],
#   ['mltD'],
#   ['gloB'],
#   ['yafS'],
#   ['rnhA'],
#   ['dnaQ'],
#   ['yafT'],
#   ['ykfM'],
#   ['yafV'],
#   ['ivy'],
#   ['fadE'],
#   ['lpcA'],
#   ['yafJ'],
#   ['yafK'],
#   ['yafQ', 'dinJ'],
#   ['yafL'],
#   ['rayT'],
#   ['dinB'],
#   ['yafN', 'yafO', 'yafP'],
#   ['pepD'],
#   ['gpt'],
#   ['frsA'],
#   ['crl'],
#   ['phoE'],
#   ['proB', 'proA'],
#   ['ykfI', 'yafW', 'ykfH', 'ykfG', 'yafX'],
#   ['ykfF'],
#   ['ykfB', 'yafY'],
#   ['yafZ'],
#   ['ykfA'],
#   ['perR'],
#   ['insI'],
#   ['insH'],
#   ['mmuP', 'mmuM'],
#   ['afuC'],
#   ['insB', 'insA'],
#   ['yagA'],
#   ['yagE', 'yagF'],
#   ['yagG', 'yagH'],
#   ['yagI'],
#   ['argF'],
#   ['insB', 'insA'],
#   ['yagK'],
#   ['yagL', 'yagM'],
#   ['yagN'],
#   ['intF'],
#   ['paoD', 'paoC', 'paoB', 'paoA'],
#   ['yagU'],
#   ['ykgJ'],
#   ['yagV', 'yagW', 'yagX', 'matC'],
#   ['matB'],
#   ['matA'],
#   ['ykgL'],
#   ['ykgO', 'ykgM'],
#   ['ykgR'],
#   ['insE', 'insF'],
#   ['ykgB', 'ykgI'],
#   ['ykgC'],
#   ['ykgD'],
#   ['ykgE', 'ykgF', 'ykgG'],
#   ['ykgH'],
#   ['betA', 'betB', 'betI'],
#   ['betT'],
#   ['yahA'],
#   ['yahB'],
#   ['yahC'],
#   ['yahD', 'yahE', 'yahF', 'yahG'],
#   ['yahI', 'yahJ'],
#   ['yahK'],
#   ['yahL'],
#   ['yahM'],
#   ['yahN'],
#   ['yahO'],
#   ['prpR'],
#   ['prpB'],
#   ['prpC', 'prpD', 'prpE'],
#   ['codB', 'codA'],
#   ['cynR'],
#   ['cynT', 'cynS', 'cynX'],
#   ['lacA'],
#   ['lacY'],
#   ['lacZ'],
#   ['lacI'],
#   ['mhpR'],
#   ['mhpA', 'mhpB', 'mhpC', 'mhpD', 'mhpF', 'mhpE'],
#   ['mhpT'],
#   ['yaiL'],
#   ['frmB'],
#   ['frmA', 'frmR'],
#   ['yaiO'],
#   ['insC', 'insD'],
#   ['yaiP'],
#   ['yaiS'],
#   ['tauA', 'tauB', 'tauC', 'tauD'],
#   ['hemB'],
#   ['insF', 'insE'],
#   ['yaiV'],
#   ['ampH'],
#   ['sbmA', 'yaiW'],
#   ['yaiY'],
#   ['yaiZ'],
#   ['ddlA'],
#   ['iraP'],
#   ['phoA'],
#   ['psiF'],
#   ['adrA'],
#   ['proC'],
#   ['yaiI'],
#   ['aroL'],
#   ['yaiA'],
#   ['aroM'],
#   ['yaiE'],
#   ['rdgC'],
#   ['mak'],
#   ['araJ'],
#   ['sbcC', 'sbcD'],
#   ['phoB'],
#   ['phoR'],
#   ['brnQ'],
#   ['proY'],
#   ['malZ'],
#   ['acpH'],
#   ['queA'],
#   ['tgt', 'yajC', 'secD', 'secF'],
#   ['yajD'],
#   ['tsx'],
#   ['yajI'],
#   ['nrdR', 'ribD'],
#   ['ribE', 'nusB'],
#   ['thiL', 'pgpA'],
#   ['yajO'],
#   ['dxs', 'ispA', 'xseB'],
#   ['thiI'],
#   ['yajL', 'panE'],
#   ['yajQ'],
#   ['yajR'],
#   ['cyoE', 'cyoD', 'cyoC', 'cyoB', 'cyoA'],
#   ['ampG', 'yajG'],
#   ['bolA'],
#   ['tig'],
#   ['clpP'],
#   ['clpX'],
#   ['lon'],
#   ['hupB'],
#   ['ppiD'],
#   ['ybaV'],
#   ['fadM'],
#   ['queC'],
#   ['ybaE'],
#   ['cof'],
#   ['ybaO', 'mdlA', 'mdlB'],
#   ['glnK', 'amtB'],
#   ['tesB'],
#   ['ybaY'],
#   ['ybaZ'],
#   ['ybaA'],
#   ['ylaB'],
#   ['ylaC'],
#   ['maa'],
#   ['hha', 'tomB'],
#   ['acrB', 'acrA'],
#   ['acrR'],
#   ['kefA'],
#   ['ybaM', 'priC'],
#   ['ybaN'],
#   ['apt'],
#   ['dnaX'],
#   ['ybaB', 'recR'],
#   ['htpG'],
#   ['adk'],
#   ['hemH'],
#   ['aes'],
#   ['gsk'],
#   ['ybaL'],
#   ['fsr'],
#   ['ushA'],
#   ['ybaK'],
#   ['ybaP'],
#   ['ybaQ'],
#   ['copA'],
#   ['ybaS', 'ybaT'],
#   ['cueR'],
#   ['ybbJ', 'qmcA'],
#   ['ybbL', 'ybbM'],
#   ['ybbN'],
#   ['ybbO', 'tesA'],
#   ['ybbA', 'ybbP'],
#   ['rhsD', 'ybbC'],
#   ['selU'],
#   ['allS'],
#   ['allA'],
#   ['allR'],
#   ['gcl', 'hyi'],
#   ['glxR'],
#   ['ybbW'],
#   ['allB'],
#   ['ybbY', 'glxK'],
#   ['ylbA', 'allC', 'allD'],
#   ['fdrA'],
#   ['ylbF', 'ybcF'],
#   ['purK', 'purE'],
#   ['lpxH', 'ppiB'],
#   ['cysS'],
#   ['ybcI'],
#   ['ybcJ', 'folD'],
#   ['sfmA'],
#   ['sfmC', 'sfmD', 'sfmH', 'sfmF'],
#   ['fimZ'],
#   ['intD'],
#   ['insE', 'insF'],
#   ['emrE'],
#   ['ybcK'],
#   ['ybcL', 'ybcM'],
#   ['ylcH', 'ybcN', 'ninE', 'ybcO', 'rusA', 'ylcG'],
#   ['quuD'],
#   ['insH'],
#   ['essD', 'rrrD', 'rzpD', 'rzoD'],
#   ['borD'],
#   ['ybcV'],
#   ['ybcW'],
#   ['ylcI'],
#   ['nohD'],
#   ['appY'],
#   ['ompT'],
#   ['envY'],
#   ['ybcH', 'nfrA', 'nfrB'],
#   ['cusS', 'cusR'],
#   ['cusC'],
#   ['cusF', 'cusB', 'cusA'],
#   ['pheP'],
#   ['mscM'],
#   ['nfsB'],
#   ['ybdF'],
#   ['ybdJ'],
#   ['ybdK'],
#   ['hokE'],
#   ['insL'],
#   ['entD'],
#   ['fepA'],
#   ['fes', 'ybdZ', 'entF'],
#   ['fepE'],
#   ['fepC', 'fepG', 'fepD'],
#   ['entS'],
#   ['fepB'],
#   ['entC', 'entE', 'entB', 'entA', 'entH'],
#   ['cstA'],
#   ['ybdD'],
#   ['ybdH'],
#   ['ybdL'],
#   ['ybdM', 'ybdN'],
#   ['ybdO'],
#   ['dsbG'],
#   ['ahpC'],
#   ['ahpF'],
#   ['uspG'],
#   ['ybdR'],
#   ['rnk'],
#   ['rna'],
#   ['citT'],
#   ['citG', 'citX', 'citF', 'citE', 'citD', 'citC'],
#   ['dpiB', 'dpiA'],
#   ['dcuC'],
#   ['pagP'],
#   ['cspE'],
#   ['crcB'],
#   ['tatE'],
#   ['lipA'],
#   ['ybeF'],
#   ['lipB'],
#   ['ybeD'],
#   ['dacA'],
#   ['rlpA', 'mrdB', 'mrdA', 'rlmH', 'ybeB'],
#   ['cobC', 'nadD', 'holA', 'lptE', 'leuS'],
#   ['ybeL'],
#   ['ybeQ'],
#   ['ybeR', 'djlB'],
#   ['ybeT'],
#   ['ybeU', 'djlC'],
#   ['hscC'],
#   ['rihA'],
#   ['gltL', 'gltK', 'gltJ'],
#   ['gltI'],
#   ['insH'],
#   ['lnt', 'ybeX'],
#   ['ybeY', 'ybeZ'],
#   ['miaB'],
#   ['ubiF'],
#   ['asnB'],
#   ['nagD', 'nagC', 'nagA'],
#   ['nagB'],
#   ['nagE'],
#   ['glnS'],
#   ['chiP'],
#   ['chiQ'],
#   ['fur', 'uof'],
#   ['fldA'],
#   ['ybfE'],
#   ['ybfF'],
#   ['seqA', 'pgm'],
#   ['ybfP'],
#   ['potE', 'speF'],
#   ['ybfK'],
#   ['kdpE', 'kdpD', 'kdpC', 'kdpB', 'kdpA', 'kdpF'],
#   ['ybfA'],
#   ['rhsC', 'ybfB'],
#   ['ybfC'],
#   ['ybfD'],
#   ['ybgA', 'phr'],
#   ['dtpD'],
#   ['ybgI', 'ybgJ', 'ybgK', 'ybgL', 'nei'],
#   ['abrB'],
#   ['ybgO', 'ybgP', 'ybgQ'],
#   ['ybgD'],
#   ['gltA'],
#   ['sdhC', 'sdhD', 'sdhA', 'sdhB'],
#   ['sucA', 'sucB'],
#   ['sucC', 'sucD'],
#   ['mngR'],
#   ['mngA', 'mngB'],
#   ['cydA', 'cydB', 'ybgT', 'ybgE'],
#   ['ybgC', 'tolQ', 'tolR'],
#   ['tolA'],
#   ['tolB', 'pal', 'ybgF'],
#   ['nadA', 'pnuC'],
#   ['zitB'],
#   ['ybgS'],
#   ['aroG'],
#   ['gpmA'],
#   ['galM', 'galK', 'galT', 'galE'],
#   ['modF'],
#   ['modE'],
#   ['ybhT'],
#   ['modA', 'modB', 'modC'],
#   ['ybhA'],
#   ['pgl'],
#   ['ybhD'],
#   ['ybhH'],
#   ['ybhI'],
#   ['ybhJ'],
#   ['ybhC'],
#   ['ybhB'],
#   ['bioA'],
#   ['bioB', 'bioF', 'bioC', 'bioD'],
#   ['uvrB'],
#   ['ybhK'],
#   ['moaA', 'moaB', 'moaC', 'moaD', 'moaE'],
#   ['ybhL'],
#   ['ybhM'],
#   ['ybhN', 'ybhO', 'ybhP'],
#   ['ybhQ'],
#   ['ybhR', 'ybhS', 'ybhF', 'ybhG', 'ybiH'],
#   ['rhlE'],
#   ['ybiA'],
#   ['dinG', 'ybiB'],
#   ['ybiC'],
#   ['ybiJ'],
#   ['ybiI'],
#   ['ybiX', 'fiu'],
#   ['mcbA'],
#   ['rlmF'],
#   ['ybiO'],
#   ['glnQ', 'glnP'],
#   ['glnH'],
#   ['dps'],
#   ['rhtA'],
#   ['ompX'],
#   ['ybiP'],
#   ['yliL'],
#   ['mntR', 'ybiR'],
#   ['ybiS'],
#   ['ybiT'],
#   ['ybiU'],
#   ['ybiV'],
#   ['ybiW', 'ybiY'],
#   ['fsaA'],
#   ['moeB', 'moeA'],
#   ['iaaA', 'gsiA', 'gsiB', 'gsiC', 'gsiD'],
#   ['yliE', 'yliF'],
#   ['rimO'],
#   ['bssR'],
#   ['yliI'],
#   ['gstB'],
#   ['dacC'],
#   ['deoR'],
#   ['ybjG'],
#   ['mdfA'],
#   ['ybjH'],
#   ['ybjI', 'ybjJ'],
#   ['ybjK'],
#   ['ybjL'],
#   ['ybjM'],
#   ['grxA'],
#   ['ybjC', 'nfsA'],
#   ['rimK'],
#   ['ybjN'],
#   ['potF'],
#   ['potG', 'potH', 'potI'],
#   ['ybjO', 'rlmD'],
#   ['artJ'],
#   ['artM', 'artQ', 'artI', 'artP'],
#   ['ybjP'],
#   ['ybjQ', 'amiD'],
#   ['ybjS'],
#   ['ybjT', 'ltaE', 'poxB'],
#   ['hcr', 'hcp'],
#   ['ybjE'],
#   ['aqpZ'],
#   ['ybjD'],
#   ['ybjX'],
#   ['macA', 'macB'],
#   ['cspD'],
#   ['clpS', 'clpA'],
#   ['infA'],
#   ['aat', 'cydC', 'cydD'],
#   ['trxB'],
#   ['lrp'],
#   ['ftsK'],
#   ['lolA', 'rarA'],
#   ['serS'],
#   ['dmsA', 'dmsB', 'dmsC'],
#   ['ycaC'],
#   ['ycaD'],
#   ['ycaM'],
#   ['ycaN'],
#   ['ycaK'],
#   ['pflA'],
#   ['pflB'],
#   ['focA'],
#   ['ycaO'],
#   ['ycaP'],
#   ['serC'],
#   ['aroA'],
#   ['ycaL'],
#   ['cmk'],
#   ['rpsA'],
#   ['ihfB'],
#   ['ycaI', 'msbA', 'lpxK', 'ycaQ'],
#   ['ycaR', 'kdsB'],
#   ['ycbJ'],
#   ['ycbC'],
#   ['smtA', 'mukF', 'mukE', 'mukB'],
#   ['ycbB'],
#   ['ycbK', 'ycbL'],
#   ['aspC'],
#   ['ompF'],
#   ['asnS'],
#   ['pncB'],
#   ['pepN'],
#   ['ssuB', 'ssuC', 'ssuD', 'ssuA', 'ssuE'],
#   ['elfA'],
#   ['elfD', 'elfC', 'elfG', 'ycbU', 'ycbV', 'ycbF'],
#   ['pyrD'],
#   ['zapC'],
#   ['ycbX'],
#   ['rlmL', 'uup'],
#   ['pqiA', 'pqiB', 'ymbA'],
#   ['rmf'],
#   ['fabA'],
#   ['ycbZ'],
#   ['matP'],
#   ['ompA'],
#   ['sulA'],
#   ['sxy'],
#   ['yccS', 'yccF'],
#   ['helD'],
#   ['mgsA'],
#   ['yccT'],
#   ['yccU'],
#   ['hspQ'],
#   ['rlmI'],
#   ['yccX'],
#   ['tusE'],
#   ['yccA'],
#   ['hyaA', 'hyaB', 'hyaC', 'hyaD', 'hyaE', 'hyaF'],
#   ['appC', 'appB', 'yccB'],
#   ['appA'],
#   ['etk', 'etp', 'gfcE', 'gfcD', 'gfcC', 'gfcB'],
#   ['gfcA'],
#   ['insA', 'insB'],
#   ['cspH'],
#   ['cspG'],
#   ['ymcE', 'gnsA'],
#   ['yccM'],
#   ['torS'],
#   ['torT'],
#   ['torR'],
#   ['torC', 'torA', 'torD'],
#   ['cbpM', 'cbpA'],
#   ['yccE'],
#   ['agp'],
#   ['yccJ', 'wrbA'],
#   ['ymdF'],
#   ['rutG', 'rutF', 'rutE', 'rutD', 'rutC', 'rutB', 'rutA'],
#   ['rutR'],
#   ['putA'],
#   ['putP'],
#   ['efeO', 'efeB'],
#   ['phoH'],
#   ['pgaD', 'pgaC', 'pgaB', 'pgaA'],
#   ['ycdT'],
#   ['insF', 'insE'],
#   ['ycdU'],
#   ['ghrA'],
#   ['ycdX', 'ycdY'],
#   ['ycdZ'],
#   ['csgG', 'csgF', 'csgE', 'csgD'],
#   ['csgB', 'csgA'],
#   ['csgC'],
#   ['ymdA'],
#   ['ymdB', 'ymdC'],
#   ['opgC'],
#   ['opgG', 'opgH'],
#   ['yceK'],
#   ['msyB'],
#   ['mdtG'],
#   ['lpxL'],
#   ['yceA'],
#   ['yceI', 'yceJ'],
#   ['yceO', 'solA'],
#   ['bssS'],
#   ['dinI'],
#   ['pyrC'],
#   ['yceB'],
#   ['grxB'],
#   ['mdtH'],
#   ['rimJ', 'yceH', 'yceM'],
#   ['murJ'],
#   ['flgN', 'flgM'],
#   ['flgA'],
#   ['flgB', 'flgC', 'flgD', 'flgE', 'flgF'],
#   ['flgG'],
#   ['flgH', 'flgI', 'flgJ'],
#   ['flgK', 'flgL'],
#   ['rne'],
#   ['yceQ'],
#   ['rluC'],
#   ['yceF'],
#   ['yceD'],
#   ['rpmF'],
#   ['plsX'],
#   ['fabH', 'fabD', 'fabG'],
#   ['acpP'],
#   ['fabF'],
#   ['pabC', 'yceG', 'tmk', 'holB', 'ycfH'],
#   ['ptsG'],
#   ['fhuE'],
#   ['hinT', 'ycfL', 'lpoB', 'thiK', 'nagZ', 'ycfP'],
#   ['ndh'],
#   ['ycfJ'],
#   ['ycfQ'],
#   ['bhsA'],
#   ['ycfS'],
#   ['mfd'],
#   ['ycfT'],
#   ['lolC', 'lolD', 'lolE', 'nagK'],
#   ['cobB'],
#   ['ycfZ', 'ymfA'],
#   ['potD', 'potC', 'potB', 'potA'],
#   ['pepT'],
#   ['ycfD'],
#   ['phoQ', 'phoP'],
#   ['purB', 'hflD', 'mnmA'],
#   ['nudJ', 'rluE'],
#   ['icd'],
#   ['ymfD', 'ymfE'],
#   ['lit'],
#   ['intE', 'xisE'],
#   ['ymfI'],
#   ['ymfJ'],
#   ['cohE'],
#   ['croE', 'ymfL', 'ymfM'],
#   ['ymfR'],
#   ['ymfQ', 'stfP', 'tfaP'],
#   ['tfaE'],
#   ['pinE'],
#   ['mcrA'],
#   ['iraM'],
#   ['ycgX'],
#   ['ycgE'],
#   ['ycgF'],
#   ['ycgZ', 'ymgA', 'ariR'],
#   ['ymgC'],
#   ['ycgG'],
#   ['ymgF'],
#   ['ymgD', 'ymgG', 'ymgI'],
#   ['ymgJ'],
#   ['minE', 'minD', 'minC'],
#   ['ycgJ'],
#   ['pliG'],
#   ['ycgL'],
#   ['ycgM'],
#   ['ycgN'],
#   ['hlyE'],
#   ['umuD', 'umuC'],
#   ['dsbB'],
#   ['nhaB'],
#   ['fadR'],
#   ['ycgB'],
#   ['dadA', 'dadX'],
#   ['cvrA'],
#   ['ldcA'],
#   ['emtA'],
#   ['ycgR'],
#   ['ymgE'],
#   ['ycgY'],
#   ['treA'],
#   ['dhaM', 'dhaL', 'dhaK'],
#   ['dhaR'],
#   ['ycgV'],
#   ['ychF'],
#   ['pth'],
#   ['ychH'],
#   ['ychM'],
#   ['prs'],
#   ['ispE', 'lolB'],
#   ['hemA', 'prfA', 'prmC', 'ychQ', 'ychA', 'kdsA'],
#   ['ldrA'],
#   ['ldrB'],
#   ['ldrC'],
#   ['chaA'],
#   ['chaB'],
#   ['chaC'],
#   ['ychN'],
#   ['ychO'],
#   ['narL', 'narX'],
#   ['narK'],
#   ['narG', 'narH', 'narJ', 'narI'],
#   ['tpr'],
#   ['purU'],
#   ['ychJ'],
#   ['rssA'],
#   ['rssB'],
#   ['galU'],
#   ['hns'],
#   ['tdk'],
#   ['adhE'],
#   ['ychE'],
#   ['oppA'],
#   ['oppB', 'oppC', 'oppD', 'oppF'],
#   ['yciU', 'cls'],
#   ['yciY'],
#   ['kch'],
#   ['yciI'],
#   ['tonB'],
#   ['yciA'],
#   ['yciB', 'yciC'],
#   ['ompW'],
#   ['yciE', 'yciF'],
#   ['yciG'],
#   ['trpA', 'trpB', 'trpC', 'trpD', 'trpE'],
#   ['trpL'],
#   ['yciV', 'yciO', 'yciQ'],
#   ['rluB'],
#   ['btuR', 'yciK'],
#   ['sohB'],
#   ['yciN'],
#   ['topA'],
#   ['cysB'],
#   ['ymiA', 'yciX'],
#   ['acnA'],
#   ['ribA'],
#   ['pgpB'],
#   ['yciS', 'yciM'],
#   ['pyrF', 'yciH'],
#   ['osmB'],
#   ['yciT'],
#   ['yciZ'],
#   ['gmr'],
#   ['ymiB'],
#   ['rnb'],
#   ['yciW'],
#   ['fabI'],
#   ['ycjD'],
#   ['sapF', 'sapD', 'sapC', 'sapB', 'sapA'],
#   ['ymjA'],
#   ['puuP'],
#   ['puuA'],
#   ['puuD', 'puuR'],
#   ['puuC', 'puuB', 'puuE'],
#   ['pspF'],
#   ['pspA'],
#   ['pspB', 'pspC', 'pspD'],
#   ['pspE'],
#   ['ycjM', 'ycjN', 'ycjO', 'ycjP', 'ycjQ', 'ycjR', 'ycjS', 'ycjT', 'ycjU'],
#   ['ompG'],
#   ['ycjW'],
#   ['ycjX', 'ycjF'],
#   ['tyrR'],
#   ['tpx'],
#   ['ycjG'],
#   ['mpaA'],
#   ['ycjY'],
#   ['ycjZ'],
#   ['mppA'],
#   ['ynaI'],
#   ['insH'],
#   ['ynaJ'],
#   ['uspE'],
#   ['fnr'],
#   ['ogt', 'abgT', 'abgB', 'abgA'],
#   ['abgR'],
#   ['smrA'],
#   ['ydaM'],
#   ['ydaN'],
#   ['dbpA'],
#   ['ttcA'],
#   ['intR', 'ydaQ'],
#   ['ydaC', 'ralR'],
#   ['recT', 'recE'],
#   ['racC'],
#   ['ydaE', 'kilR'],
#   ['sieB'],
#   ['ydaF', 'ydaG'],
#   ['racR'],
#   ['ydaS', 'ydaT', 'ydaU', 'ydaV'],
#   ['rzoR'],
#   ['trkG'],
#   ['ynaK'],
#   ['insH'],
#   ['stfR', 'tfaR'],
#   ['pinR'],
#   ['ynaE'],
#   ['uspF'],
#   ['ompN'],
#   ['ydbK'],
#   ['ydbJ'],
#   ['hslJ'],
#   ['ldhA'],
#   ['ydbH', 'ynbE', 'ydbL'],
#   ['feaR'],
#   ['feaB'],
#   ['tynA'],
#   ['paaZ'],
#   ['paaA',
#    'paaB',
#    'paaC',
#    'paaD',
#    'paaE',
#    'paaF',
#    'paaG',
#    'paaH',
#    'paaI',
#    'paaJ',
#    'paaK'],
#   ['paaX', 'paaY'],
#   ['ynbG'],
#   ['insD', 'insC'],
#   ['insI'],
#   ['ydbC'],
#   ['ydbD'],
#   ['ynbA', 'ynbB', 'ynbC', 'ynbD'],
#   ['azoR'],
#   ['hrpA'],
#   ['ydcF'],
#   ['aldA'],
#   ['cybB'],
#   ['ydcA'],
#   ['hokB', 'mokB'],
#   ['trg'],
#   ['ydcI'],
#   ['ydcJ'],
#   ['opgD'],
#   ['ydcH'],
#   ['rimL'],
#   ['ydcK'],
#   ['tehA', 'tehB'],
#   ['ydcL'],
#   ['insQ'],
#   ['ydcO'],
#   ['ydcN'],
#   ['ydcP'],
#   ['yncJ'],
#   ['hicA', 'hicB'],
#   ['ydcR'],
#   ['ydcS', 'ydcT', 'ydcU', 'ydcV', 'prr'],
#   ['yncL'],
#   ['ydcX'],
#   ['ydcY'],
#   ['ydcZ', 'yncA'],
#   ['curA'],
#   ['mcbR'],
#   ['yncD'],
#   ['yncE'],
#   ['ansP'],
#   ['yncG'],
#   ['yncH'],
#   ['ydcD'],
#   ['ydcC'],
#   ['pptA'],
#   ['yddH'],
#   ['nhoA'],
#   ['yddE'],
#   ['narV', 'narW', 'narY', 'narZ'],
#   ['narU'],
#   ['yddJ'],
#   ['yddG'],
#   ['fdnG', 'fdnH', 'fdnI'],
#   ['yddM'],
#   ['adhP'],
#   ['maeA'],
#   ['sra'],
#   ['bdm'],
#   ['osmC'],
#   ['ddpF', 'ddpD', 'ddpC', 'ddpB', 'ddpA', 'ddpX'],
#   ['dosP', 'dosC'],
#   ['yddW'],
#   ['gadC'],
#   ['gadB'],
#   ['pqqL', 'yddB', 'yddA'],
#   ['ydeM'],
#   ['ydeN'],
#   ['ydeO'],
#   ['safA'],
#   ['ydeP'],
#   ['ydeQ'],
#   ['ydeR', 'ydeS'],
#   ['hipA', 'hipB'],
#   ['lsrK'],
#   ['lsrR'],
#   ['lsrA', 'lsrC', 'lsrD', 'lsrB', 'lsrF', 'lsrG'],
#   ['tam'],
#   ['yneE'],
#   ['uxaB'],
#   ['yneF'],
#   ['yneG', 'yneH'],
#   ['sad'],
#   ['yneJ'],
#   ['yneK'],
#   ['ydeA'],
#   ['marC'],
#   ['marR', 'marA', 'marB'],
#   ['eamA'],
#   ['ydeE'],
#   ['yneM'],
#   ['ydeH'],
#   ['ydeI'],
#   ['ydeJ'],
#   ['dcp'],
#   ['ydfG'],
#   ['ydfH'],
#   ['ydfZ'],
#   ['ydfI'],
#   ['ydfK'],
#   ['pinQ'],
#   ['tfaQ', 'stfQ'],
#   ['ynfO'],
#   ['ydfO'],
#   ['gnsB'],
#   ['ynfN'],
#   ['cspI'],
#   ['rzpQ', 'rzoQ'],
#   ['rrrQ', 'ydfR', 'essQ'],
#   ['cspB'],
#   ['cspF'],
#   ['quuQ', 'ydfU'],
#   ['rem'],
#   ['hokD'],
#   ['relE', 'relB'],
#   ['ydfV'],
#   ['flxA'],
#   ['dicC'],
#   ['dicA'],
#   ['ydfA', 'ydfB', 'ydfC'],
#   ['dicB', 'ydfD'],
#   ['rspB', 'rspA'],
#   ['ynfA'],
#   ['ynfB', 'speG'],
#   ['ynfC'],
#   ['ynfD'],
#   ['ynfE'],
#   ['ynfF', 'ynfG', 'ynfH', 'dmsD'],
#   ['clcB'],
#   ['ynfK'],
#   ['dgsA'],
#   ['ynfL'],
#   ['ynfM'],
#   ['asr'],
#   ['ydgU'],
#   ['ydgD'],
#   ['mdtI', 'mdtJ'],
#   ['tqsA'],
#   ['pntB', 'pntA'],
#   ['ydgH'],
#   ['ydgI', 'folM'],
#   ['ydgC'],
#   ['rstA', 'rstB'],
#   ['tus'],
#   ['fumC'],
#   ...])

# %%
predict_operons('Halobacterium_NRC1.ptt')
# Out:
# (1464,
#  [['-', 'yvrO', '-'],
#   ['-'],
#   ['glmS', 'graD5', 'graD2'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-', '-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-', '-'],
#   ['ntp'],
#   ['-', '-', '-'],
#   ['ugd'],
#   ['graD6'],
#   ['-', '-'],
#   ['rfbU1'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['lpg'],
#   ['-'],
#   ['lpb'],
#   ['galE2'],
#   ['graD3'],
#   ['gmd'],
#   ['-', '-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['moaE'],
#   ['moeB'],
#   ['moaA'],
#   ['moeA2', 'moeA1'],
#   ['pimT1', '-'],
#   ['-'],
#   ['-'],
#   ['gapB'],
#   ['hsp2'],
#   ['rimK'],
#   ['rpl10e'],
#   ['cspD1'],
#   ['-'],
#   ['serA3'],
#   ['-'],
#   ['rmeM', 'rmeS'],
#   ['rmeR', '-'],
#   ['-'],
#   ['-'],
#   ['yusZ1'],
#   ['-'],
#   ['-', '-'],
#   ['-', '-'],
#   ['-'],
#   ['trp1', '-'],
#   ['-', '-'],
#   ['-'],
#   ['hsp4'],
#   ['-'],
#   ['-'],
#   ['rpa'],
#   ['hpyA', 'aup'],
#   ['cca'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['zntA'],
#   ['-', '-'],
#   ['prrC'],
#   ['-'],
#   ['merA'],
#   ['-'],
#   ['oxlT'],
#   ['kdgK', 'mutL'],
#   ['boa1'],
#   ['gdhB', 'alkK'],
#   ['mutS1'],
#   ['hef'],
#   ['psmB'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['mutS2'],
#   ['cat1', 'trkA1'],
#   ['-'],
#   ['rpl15e'],
#   ['-'],
#   ['-'],
#   ['hop'],
#   ['lpl'],
#   ['xthA'],
#   ['-'],
#   ['pepB1'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['ftsZ2'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-', '-'],
#   ['-', '-', '-'],
#   ['-', '-', '-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['gspE1'],
#   ['-', '-', '-'],
#   ['moxR'],
#   ['htrA'],
#   ['-'],
#   ['guaAa', '-', '-'],
#   ['-', '-'],
#   ['-', 'rpl37ae'],
#   ['-'],
#   ['-'],
#   ['truD', '-'],
#   ['-', 'dcd', '-'],
#   ['-', 'fbr'],
#   ['-', '-'],
#   ['-'],
#   ['tfbG'],
#   ['-', '-'],
#   ['-'],
#   ['ipp'],
#   ['-', '-'],
#   ['-'],
#   ['ftsZ4'],
#   ['-', '-', '-'],
#   ['-', '-', '-'],
#   ['-', 'crtI3'],
#   ['-'],
#   ['soxB'],
#   ['-', '-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-', '-', '-'],
#   ['pnm'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['lon'],
#   ['-'],
#   ['trpC', 'trpB', 'trpA', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['aroD'],
#   ['tfbF'],
#   ['-'],
#   ['dpg'],
#   ['-'],
#   ['-'],
#   ['ids', '-', '-', 'pykA'],
#   ['metG'],
#   ['gadD', 'caaX', 'ppsA'],
#   ['-'],
#   ['-'],
#   ['gptA1'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', 'smc1', '-'],
#   ['gatB'],
#   ['-'],
#   ['-'],
#   ['topA'],
#   ['-', '-', '-'],
#   ['htr14'],
#   ['-', '-'],
#   ['-'],
#   ['-', 'nfi'],
#   ['yusZ3'],
#   ['arsA1'],
#   ['-', '-'],
#   ['-'],
#   ['acd1'],
#   ['-'],
#   ['nusG', 'secE'],
#   ['ftsZ1', '-'],
#   ['caa'],
#   ['aroE', '-', 'trpE2', 'trpG2', 'ilvE1', '-'],
#   ['-'],
#   ['graD1'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['nthA1'],
#   ['-'],
#   ['epf2'],
#   ['-'],
#   ['proS'],
#   ['-', '-'],
#   ['egsA'],
#   ['-'],
#   ['-', '-'],
#   ['rfbU2'],
#   ['folP', 'purH'],
#   ['purB'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['cyc'],
#   ['nac', 'pimT2'],
#   ['rpoM'],
#   ['yfmO2'],
#   ['fad2'],
#   ['-'],
#   ['-'],
#   ['apa'],
#   ['-'],
#   ['-', 'nhaC1'],
#   ['-'],
#   ['-'],
#   ['ferA3'],
#   ['-'],
#   ['-'],
#   ['rspA', 'dapA', '-'],
#   ['gcd', 'pyrE1'],
#   ['-'],
#   ['phoU'],
#   ['pstB2', 'pstA2', 'pstC2'],
#   ['phoX'],
#   ['prp1'],
#   ['nodP'],
#   ['aspS'],
#   ['-', '-', 'nosF2', '-'],
#   ['yafB'],
#   ['-'],
#   ['-', 'trp3'],
#   ['-', '-'],
#   ['porB', 'porA'],
#   ['-'],
#   ['-'],
#   ['-', 'yajO1'],
#   ['mcmA1'],
#   ['-'],
#   ['-'],
#   ['acs1'],
#   ['-', 'hat1', '-', '-'],
#   ['dnaJ'],
#   ['dnaK'],
#   ['-', 'grpE'],
#   ['-'],
#   ['-', 'cna'],
#   ['ppd'],
#   ['yfmO1'],
#   ['aspB1'],
#   ['-'],
#   ['gbp5'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['prrIV2'],
#   ['-'],
#   ['ppe', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['polB1'],
#   ['inb'],
#   ['yurY', '-', '-'],
#   ['-'],
#   ['troR'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['sirR'],
#   ['-', '-'],
#   ['imp'],
#   ['thrC2'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-', 'eif2a', 'rps27e', 'rpl44e'],
#   ['-'],
#   ['-'],
#   ['sgb'],
#   ['-'],
#   ['apt'],
#   ['-', '-', 'ndhG2'],
#   ['-', '-', '-', 'mnhG', '-', '-'],
#   ['dfp'],
#   ['-'],
#   ['-'],
#   ['ywaD'],
#   ['-', '-'],
#   ['-', '-'],
#   ['-', 'cyb', '-', '-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['nthA2'],
#   ['dmd'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['yrhA'],
#   ['-', '-'],
#   ['ubiA'],
#   ['-'],
#   ['-'],
#   ['-', 'htr16'],
#   ['-'],
#   ['-'],
#   ['edp'],
#   ['-'],
#   ['yngE'],
#   ['-'],
#   ['maoC2'],
#   ['citE'],
#   ['gdhA1'],
#   ['aspB2', 'ribH'],
#   ['-'],
#   ['purK', 'purE'],
#   ['nolB', 'ndhG1', 'ndhG5'],
#   ['ndhG4', 'nolD'],
#   ['-'],
#   ['-', 'nolC', 'nuoL', 'nuoM'],
#   ['ndhG3'],
#   ['-', 'imd1'],
#   ['-'],
#   ['mcmA1'],
#   ['-'],
#   ['-'],
#   ['coxA2'],
#   ['-', '-'],
#   ['coxC'],
#   ['birL'],
#   ['coxB1'],
#   ['ctaB', 'trp4', '-', '-'],
#   ['-', '-'],
#   ['mcmA2', '-'],
#   ['-'],
#   ['-', 'acaB1', '-', 'acd4'],
#   ['fdfT'],
#   ['hbd1'],
#   ['-'],
#   ['-', 'fbp', '-'],
#   ['-'],
#   ['trp5', '-'],
#   ['-'],
#   ['nthB'],
#   ['-'],
#   ['-'],
#   ['yvgX'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['thiC'],
#   ['afsQ2'],
#   ['-'],
#   ['-'],
#   ['araL'],
#   ['dip2', 'pepQ1'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['tpc'],
#   ['-'],
#   ['tfbB'],
#   ['hlx2', 'kinA2'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['spoVR', '-', 'prkA'],
#   ['prk'],
#   ['-'],
#   ['-'],
#   ['galE1'],
#   ['ylnA', '-'],
#   ['-'],
#   ['tfeA', '-', '-', 'dip3'],
#   ['-'],
#   ['ybjG'],
#   ['-'],
#   ['-'],
#   ['prp2'],
#   ['-', '-', '-'],
#   ['aldY2'],
#   ['-'],
#   ['acd2'],
#   ['taqD', '-'],
#   ['-', '-'],
#   ['-'],
#   ['pssA'],
#   ['pcy'],
#   ['rps3e', '-'],
#   ['-', 'rps15p'],
#   ['htr6', 'yufN'],
#   ['hcpC'],
#   ['cgs'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['htr4'],
#   ['gabD'],
#   ['-'],
#   ['-'],
#   ['htr18', 'potD'],
#   ['-'],
#   ['yfmJ'],
#   ['chi'],
#   ['-', '-'],
#   ['-', '-'],
#   ['gspE2', 'gdb'],
#   ['-'],
#   ['-'],
#   ['-', 'dmsA', 'hmoA', 'moz', '-'],
#   ['-'],
#   ['idr2'],
#   ['-'],
#   ['-', 'ssrA'],
#   ['-'],
#   ['icfA'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['rpoL'],
#   ['hisF'],
#   ['-'],
#   ['-'],
#   ['purL'],
#   ['-', 'asnA'],
#   ['-', 'tfbD'],
#   ['gatC', 'gatA'],
#   ['ykhA'],
#   ['traB', '-'],
#   ['purM'],
#   ['-', '-'],
#   ['psmA'],
#   ['lig'],
#   ['PHO2'],
#   ['-'],
#   ['top6A', 'top6B'],
#   ['gyrB', 'gyrA'],
#   ['imd2', 'yjlD', '-', '-'],
#   ['udp2'],
#   ['cda'],
#   ['rbsC1', 'rbsC2', 'rbsA', '-'],
#   ['pmu2', '-'],
#   ['-'],
#   ['putP', '-'],
#   ['-', '-'],
#   ['-'],
#   ['hakA'],
#   ['ark', 'hrg'],
#   ['-'],
#   ['gst'],
#   ['-', 'potA1', 'sfuB', 'ibp'],
#   ['-'],
#   ['-'],
#   ['-', 'mak'],
#   ['yvbT'],
#   ['acaB2', '-'],
#   ['yqjM'],
#   ['-'],
#   ['noxC'],
#   ['-'],
#   ['gap'],
#   ['gufA'],
#   ['ACS3', '-'],
#   ['cheW2'],
#   ['-'],
#   ['-'],
#   ['minD1', 'fapJ', 'gspE3', 'flaH', '-', '-', '-'],
#   ['fapE', 'htr15'],
#   ['-'],
#   ['flaB1'],
#   ['flaB2'],
#   ['flaB3'],
#   ['cpcE'],
#   ['-'],
#   ['-'],
#   ['cheR'],
#   ['cheD', '-', 'cheC1', 'cheA', 'cheB', 'cheY', 'cheW1'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['boa4'],
#   ['acs2'],
#   ['yajO2'],
#   ['-'],
#   ['-'],
#   ['guaB'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['flaA1a'],
#   ['flaA2'],
#   ['-', '-'],
#   ['htr13'],
#   ['yqjH'],
#   ['-', '-'],
#   ['adh3', '-', '-', '-', '-', '-', '-'],
#   ['tpiA', '-', 'pgsA', '-', 'hisC1'],
#   ['-'],
#   ['-', '-'],
#   ['hpcE'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['udg1'],
#   ['-'],
#   ['-'],
#   ['gtl'],
#   ['ptp'],
#   ['graD4'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['rfbQ'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['exoM'],
#   ['tot'],
#   ['-'],
#   ['gpdA1'],
#   ['cinR', 'lfl1', 'ykfB2'],
#   ['menA'],
#   ['opuD'],
#   ['menB'],
#   ['menD', 'menF', 'yuiH'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['purA'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['cysS'],
#   ['-', '-'],
#   ['-'],
#   ['rpl12p', 'rplP0', 'rpl1P'],
#   ['rpl11p'],
#   ['-'],
#   ['drg', '-'],
#   ['glo1'],
#   ['-'],
#   ['lds'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['aspC2'],
#   ['TRH7'],
#   ['korB', 'korA'],
#   ['-', 'mrp'],
#   ['rps13p', 'rps4p', 'rps11p', 'rpb3'],
#   ['rpl18e', 'rpl13p', 'rps9p', 'rpoN', 'rpoK', 'eno', 'rps2P'],
#   ['-'],
#   ['mvk', 'argB'],
#   ['-', 'idsA'],
#   ['-'],
#   ['gltX'],
#   ['-', 'hsp3'],
#   ['rpl7ae', 'rps28e', 'rpl24e', 'ndk'],
#   ['-'],
#   ['hemK', '-'],
#   ['ksgA', '-', '-', 'rpl21e'],
#   ['metB'],
#   ['ef1B', '-'],
#   ['phoR'],
#   ['nop56/58', 'fib'],
#   ['-', '-'],
#   ['msrA', 'flaA1b'],
#   ['-'],
#   ['nirJ', '-'],
#   ['pqqE'],
#   ['pan1', 'hcpD'],
#   ['-'],
#   ['sod1'],
#   ['ACD3'],
#   ['-'],
#   ['-', '-'],
#   ['bcp'],
#   ['-'],
#   ['-'],
#   ['fucA', '-', 'gdhA2'],
#   ['-'],
#   ['-'],
#   ['hutU', 'hutG', 'hutI', 'hutH'],
#   ['-'],
#   ['-'],
#   ['pai1', 'pgk'],
#   ['-'],
#   ['urk'],
#   ['-'],
#   ['orc8'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['aroC'],
#   ['psc'],
#   ['pepQ2'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-', 'yhdG'],
#   ['surE'],
#   ['-', '-'],
#   ['-'],
#   ['ybhF', '-', '-'],
#   ['helA'],
#   ['yhcR', '-', '-'],
#   ['ribG'],
#   ['-', 'trxB2'],
#   ['-'],
#   ['-'],
#   ['eif2b'],
#   ['-'],
#   ['-'],
#   ['ogg'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', 'moaC'],
#   ['hflX2', '-'],
#   ['-', '-', '-'],
#   ['trkA5', '-', 'trkH1'],
#   ['trh2'],
#   ['-', '-'],
#   ['-', '-'],
#   ['slyD'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['cysK'],
#   ['-'],
#   ['-'],
#   ['purD'],
#   ['sdhA', 'sdhB', 'sdhD', 'sdhC'],
#   ['alkA'],
#   ['hbd2'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['cbp', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['fprA'],
#   ['-'],
#   ['-'],
#   ['sod2'],
#   ['phr2', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['fabG', '-'],
#   ['-'],
#   ['dchpS'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['trh6'],
#   ['gatB1', '-', '-', 'fumC'],
#   ['-', 'rad2', '-'],
#   ['-'],
#   ['ocd2'],
#   ['-'],
#   ['-', 'srp19', 'btuF'],
#   ['btuC', 'btuD'],
#   ['-'],
#   ['kinA1'],
#   ['-'],
#   ['-'],
#   ['asnC', 'suhB'],
#   ['-'],
#   ['-', '-'],
#   ['rad3a', '-', 'yvoF'],
#   ['-', '-', '-'],
#   ['-'],
#   ['-', '-'],
#   ['htr9'],
#   ['-'],
#   ['-'],
#   ['-', '-', '-'],
#   ['-'],
#   ['trh1'],
#   ['-'],
#   ['-'],
#   ['ush'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['glyA'],
#   ['folD'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['htlA'],
#   ['-'],
#   ['-'],
#   ['dhs'],
#   ['rps17E', 'asd'],
#   ['serA2'],
#   ['-'],
#   ['-', 'htr12'],
#   ['hisD'],
#   ['-', '-'],
#   ['-'],
#   ['yfkN', '-'],
#   ['eif2bd'],
#   ['-'],
#   ['-', '-', '-'],
#   ['-'],
#   ['crtB1'],
#   ['-'],
#   ['-', 'cdc48a'],
#   ['blp'],
#   ['bat', 'brp'],
#   ['-'],
#   ['bop'],
#   ['-'],
#   ['pri', '-'],
#   ['cdc48b', '-'],
#   ['est'],
#   ['-', '-'],
#   ['panB'],
#   ['-'],
#   ['-'],
#   ['sat'],
#   ['acd5'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['boa2'],
#   ['-'],
#   ['-'],
#   ['purF'],
#   ['rpl37e', 'snp', 'celM'],
#   ['-'],
#   ['-'],
#   ['hel'],
#   ['-'],
#   ['htr10'],
#   ['pelA'],
#   ['-'],
#   ['-', '-', '-'],
#   ['-', 'tdk'],
#   ['-'],
#   ['-'],
#   ['mutY'],
#   ['htr8'],
#   ['-'],
#   ['-'],
#   ['trp6'],
#   ['nac'],
#   ['mmdA', '-'],
#   ['acc'],
#   ['-'],
#   ['-'],
#   ['birA'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['ywfD'],
#   ['sucC', 'sucD'],
#   ['zim'],
#   ['clc'],
#   ['-', '-'],
#   ['-'],
#   ['cbiT', 'cbiL', 'cbiF', 'cbiG', 'cobH', 'cbiH', '-', '-', '-', '-', '-'],
#   ['hmcA'],
#   ['cobN', 'cbiC', 'cbiJ'],
#   ['-'],
#   ['-', 'cbiA', 'cobI', 'cbiP'],
#   ['-', '-'],
#   ['-', '-', 'hisC2', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['cysT2', '-'],
#   ['tfx'],
#   ['gcvP2', 'gcvP1'],
#   ['gdcH', 'gcvT'],
#   ['cheC2'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['mvaB'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', '-'],
#   ['rfcB'],
#   ['ccp'],
#   ['mdh'],
#   ['-'],
#   ['-'],
#   ['aad'],
#   ['-'],
#   ['cbiO2'],
#   ['cbiQ', 'cbiN', 'cbiM'],
#   ['hcpA'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['nrdB2'],
#   ['-'],
#   ['trpG1', 'trpE1', 'trpF', 'trpD'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['cdc48e'],
#   ['-', '-'],
#   ['-'],
#   ['-'],
#   ['htr1', 'sop1'],
#   ['-'],
#   ['-'],
#   ['radB'],
#   ['-'],
#   ['cdc48c'],
#   ['rps8e'],
#   ['-', '-'],
#   ['pyrF'],
#   ['-'],
#   ['-', '-'],
#   ['gbp2', '-'],
#   ['-'],
#   ['crtB2'],
#   ['-', 'ubiA', 'crtI1', 'mch'],
#   ['-'],
#   ['-',
#    'rpl3p',
#    'rpl4lp',
#    'rplW',
#    'rpl2p',
#    'rps19p',
#    'rpl22p',
#    'rps3p',
#    'rpmC',
#    '-',
#    'rps17p',
#    'rpl14p',
#    'rpl24p',
#    'rps4e',
#    'rpl5p',
#    'rps14P',
#    'rps8p',
#    'rpl6p',
#    'rpl32e',
#    'rpl19e',
#    'rpl18p',
#    'rps5p',
#    'rpl30p',
#    'rpl15p',
#    'secY'],
#   ['-'],
#   ['trkH2'],
#   ['-'],
#   ['adk'],
#   ['htlB'],
#   ['cmk', 'sus'],
#   ['-'],
#   ['htr17', '-'],
#   ['-'],
#   ['-', 'htlC', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['gbp1'],
#   ['-'],
#   ['-'],
#   ['phr1', 'crtI2'],
#   ['eif1a2'],
#   ['-', 'htr7'],
#   ['htr5', 'proX'],
#   ['sop2', 'htr2'],
#   ['-', 'speB', 'eif5a'],
#   ['-', '-'],
#   ['-'],
#   ['pgp'],
#   ['phhB'],
#   ['hemA', '-', 'nirH'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-', 'panF'],
#   ['-'],
#   ['-', '-', '-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['thrB'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['hsp1', '-'],
#   ['noxA'],
#   ['-'],
#   ['-'],
#   ['-'],
#   ['eye'],
#   ['carB'],
#   ['carA'],
#   ['trh3', 'idi', '-'],
#   ['-', 'adh4'],
#   ['moaB', '-'],
#   ['-'],
#   ['-'],
#   ['guaAb', 'pyrG'],
#   ['-', '-'],
#   ['-'],
#   ['hyrA'],
#   ['thrS'],
#   ['cspD2'],
#   ['ykfB1', '-'],
#   ['-'],
#   ['-'],
#   ['-', 'ansA', '-'],
#   ['-', '-'],
#   ['pchA'],
#   ...])

# %%
predict_operons('Synechocystis_PCC6803_uid159873.ptt')
# Out:
# (2521,
#  [['slr0612'],
#   ['slr0613'],
#   ['sll0558'],
#   ['sll1214'],
#   ['sll1213'],
#   ['rfbD'],
#   ['psbA2'],
#   ['speA'],
#   ['ligA'],
#   ['slr1315'],
#   ['fecC'],
#   ['fecD'],
#   ['fecE', 'fecB'],
#   ['iutA'],
#   ['pchR'],
#   ['sll1204', 'sll1203', 'sll1202'],
#   ['fhuA'],
#   ['pcrR'],
#   ['sll1407'],
#   ['fhuA'],
#   ['sll1405', 'exbB'],
#   ['slr1484'],
#   ['slr1485'],
#   ['slr1488'],
#   ['pchR'],
#   ['fhuA', 'fecB'],
#   ['fecB', 'slr1493'],
#   ['slr1494'],
#   ['sll1401'],
#   ['sll1400', 'ssl2733', 'sll1399', 'psbW'],
#   ['slr1495'],
#   ['sll1397'],
#   ['sll1396'],
#   ['hypD'],
#   ['rfbD', 'msrA'],
#   ['glgA'],
#   ['sll1392'],
#   ['slr1501'],
#   ['slr1113'],
#   ['slr1114', 'slr1115', 'slr1116'],
#   ['slr1117'],
#   ['sll1064'],
#   ['rffM'],
#   ['sll1063'],
#   ['slr1119'],
#   ['sll1062', 'sll1061', 'sll1060', 'ssl2069'],
#   ['ssr1853'],
#   ['hofD'],
#   ['adk'],
#   ['dapB'],
#   ['trx'],
#   ['purL'],
#   ['slr1122'],
#   ['sll1054', 'sll1053'],
#   ['gmk'],
#   ['gpmB'],
#   ['crtX'],
#   ['sll1052'],
#   ['cpcF'],
#   ['sll1049'],
#   ['slr1127'],
#   ['slr1128'],
#   ['rne'],
#   ['rhnB'],
#   ['mutT'],
#   ['pnp'],
#   ['lepB'],
#   ['me'],
#   ['cysM'],
#   ['ipk'],
#   ['sll0710', 'sll0709'],
#   ['ksgA'],
#   ['slr0722', 'slr0723'],
#   ['sohA'],
#   ['slr0725'],
#   ['slr0727'],
#   ['slr0728'],
#   ['slr0729'],
#   ['slr0730', 'slr0731'],
#   ['nifS'],
#   ['slr0732'],
#   ['sll0703', 'sll0702'],
#   ['ssl1328'],
#   ['xerC'],
#   ['ssl1326'],
#   ['slr0734'],
#   ['sll0700', 'sll0699'],
#   ['ycf26'],
#   ['psaD'],
#   ['trpE'],
#   ['crtE'],
#   ['slr0740'],
#   ['sll0696'],
#   ['phoU'],
#   ['slr0742'],
#   ['nusA'],
#   ['ssr1238'],
#   ['infB', 'slr0236'],
#   ['glgX'],
#   ['slr0238'],
#   ['ssl0426'],
#   ['cbiF'],
#   ['slr0240', 'slr0241'],
#   ['bcp', 'slr0243'],
#   ['sll0230'],
#   ['slr0244'],
#   ['psbM'],
#   ['slr0245'],
#   ['sll0228', 'ppiB'],
#   ['ycf4'],
#   ['sll0225', 'sll0224'],
#   ['slr0249'],
#   ['slr0250', 'slr0251', 'cobK'],
#   ['psaK'],
#   ['ssl0410', 'ndhB'],
#   ['phoA'],
#   ['sgl0002', 'petN'],
#   ['slr0254'],
#   ['bcp'],
#   ['glmS'],
#   ['sll0219'],
#   ['sll0218', 'sll0217'],
#   ['ctpB'],
#   ['sll0216'],
#   ['slr1411'],
#   ['atpC'],
#   ['atpA'],
#   ['atpD', 'atpF', 'atpG'],
#   ['atpH'],
#   ['atpI'],
#   ['atp1'],
#   ['slr1413'],
#   ['slr1414', 'slr1415'],
#   ['morR'],
#   ['slr1417'],
#   ['sll1319', 'sll1318'],
#   ['sll1041', 'sll1040'],
#   ['folK'],
#   ['slr1094'],
#   ['sll1039'],
#   ['slr1095'],
#   ['phdD', 'slr1097'],
#   ['slr1098'],
#   ['ubiX'],
#   ['slr1100'],
#   ['slr1101'],
#   ['slr1102'],
#   ['slr1103', 'slr1104'],
#   ['fus'],
#   ['sll1037'],
#   ['sll1036'],
#   ['ssl2009'],
#   ['upp'],
#   ['phb'],
#   ['slr1107'],
#   ['sll1033'],
#   ['ccmN', 'ccmM'],
#   ['ccmL', 'ccmK1'],
#   ['ccmK2'],
#   ['gltD'],
#   ['ank', 'slr1110'],
#   ['slr1772'],
#   ['sll1686'],
#   ['ssr2972', 'slr1773', 'slr1774'],
#   ['slr1776'],
#   ['ycf10'],
#   ['chlD'],
#   ['slr1778'],
#   ['cad', 'sll1682'],
#   ['pdxJ', 'slr1780'],
#   ['sll1681', 'msrB', 'hhoA'],
#   ['ycf29'],
#   ['bvdR'],
#   ['sll1678'],
#   ['sll1677'],
#   ['malQ'],
#   ['sll1675'],
#   ['slr1787'],
#   ['slr1788', 'slr1789'],
#   ['sll1673', 'sll1672'],
#   ['sll1671'],
#   ['slr1790'],
#   ['cysH'],
#   ['hrcA'],
#   ['aroK'],
#   ['talB'],
#   ['ssr2998'],
#   ['slr1794'],
#   ['msrA'],
#   ['ssr3000'],
#   ['mom72'],
#   ['dnaJ'],
#   ['slr1796'],
#   ['sll1665'],
#   ['sll1664', 'sll1663', 'pheA'],
#   ['pleD'],
#   ['sll1660'],
#   ['cofH'],
#   ['sll1658'],
#   ['slr1799'],
#   ['slr1800'],
#   ['sll1656', 'birA', 'sll1654'],
#   ['menG'],
#   ['sll1652'],
#   ['icd', 'slr1290'],
#   ['sll1201'],
#   ['ndhD2'],
#   ['sll1200'],
#   ['slr1293'],
#   ['ycf19'],
#   ['sufA'],
#   ['trmD', 'ssl2384'],
#   ['pfkA'],
#   ['slr1298'],
#   ['psbU'],
#   ['sll1193'],
#   ['slr1299'],
#   ['ubiH'],
#   ['sll1192', 'sll1191'],
#   ['ssr2153'],
#   ['slr1301', 'slr1302', 'slr1303'],
#   ['glcE'],
#   ['slr1305'],
#   ['slr1306'],
#   ['sll1188'],
#   ['lgt', 'sll1186'],
#   ['hemF'],
#   ['ho1'],
#   ['slr1307'],
#   ['rpl28'],
#   ['slr0962'],
#   ['sll0943'],
#   ['sir'],
#   ['slr0964'],
#   ['dnaN'],
#   ['trpA'],
#   ['slr0967'],
#   ['sll0939', 'sll0938', 'ssl1792', 'sll0936'],
#   ['cbiH'],
#   ['slr0971'],
#   ['ccmA'],
#   ['sll0933', 'rps15'],
#   ['sll0932'],
#   ['sll0931'],
#   ['sll0930', 'apcD'],
#   ['metX'],
#   ['dusA', 'sll0925'],
#   ['infC'],
#   ['slr0975'],
#   ['sll0924'],
#   ['epsB'],
#   ['sll0922'],
#   ['slr0976', 'slr0977'],
#   ['slr0978'],
#   ['slr0980'],
#   ['slr0981'],
#   ['rfbB', 'rfbF', 'rfbG', 'rfbC', 'slr1610', 'slr1611'],
#   ['slr1612'],
#   ['slr1613'],
#   ['slr1614'],
#   ['rfbE', 'slr1616', 'slr1617', 'slr1618', 'slr1619'],
#   ['slr1062'],
#   ['slr1063', 'rfbU'],
#   ['slr1065'],
#   ['slr1066', 'galE'],
#   ['slr1068'],
#   ['slr1069', 'slr1070'],
#   ['slr1071', 'yefA'],
#   ['slr1073', 'slr1074'],
#   ['slr1075'],
#   ['slr1076', 'slr1077'],
#   ['ssr1765', 'ssr1766'],
#   ['galE', 'slr1079'],
#   ['ssr1768'],
#   ['slr1081', 'slr1082'],
#   ['slr1083'],
#   ['slr1084'],
#   ['slr1085'],
#   ['slr1087'],
#   ['sll1025', 'ssl1972'],
#   ['sll1024'],
#   ['sucC', 'sll1022'],
#   ['sll1021', 'sll1020'],
#   ['obgE', 'hliA'],
#   ['HAGH1'],
#   ['pyrC'],
#   ['amt2'],
#   ['slr1400'],
#   ['slr0670'],
#   ['nucH'],
#   ['sll0654'],
#   ['cysC'],
#   ['exbB'],
#   ['slr0678', 'fmu/fmv'],
#   ['slr0680', 'slr0681'],
#   ['hisD'],
#   ['sll0651', 'sll0650'],
#   ['sll0649', 'lim'],
#   ['sll0647', 'cyaA', 'sll0645'],
#   ['sll0644'],
#   ['slr0686'],
#   ['ureG'],
#   ['pleD'],
#   ['sll0641', 'Sac1'],
#   ['slr0688'],
#   ['ssr1155', 'slr0689'],
#   ['sll0639'],
#   ['sll0638'],
#   ['ycf45'],
#   ['thiE'],
#   ['btpA'],
#   ['slr0695'],
#   ['slr1590'],
#   ['slr1591'],
#   ['slr1592'],
#   ['slr1593'],
#   ['slr1594'],
#   ['slr1595'],
#   ['sll1516'],
#   ['pxcA'],
#   ['sll1515'],
#   ['slr1597'],
#   ['hsp17'],
#   ['ccsA'],
#   ['sll1512'],
#   ['lipA'],
#   ['sll1511'],
#   ['sll1510'],
#   ['ycf20'],
#   ['slr1599'],
#   ['slr1600'],
#   ['psaM'],
#   ['slr1601'],
#   ['lpxC'],
#   ['sll1507'],
#   ['slr1603'],
#   ['ftsH'],
#   ['ssr2699'],
#   ['vapC', 'vapB'],
#   ['ssl2920'],
#   ['sll1505', 'sll1504'],
#   ['sll1503'],
#   ['gltB'],
#   ['ssr2708'],
#   ['ssr2711'],
#   ['gdhB'],
#   ['cbiA', 'sll1500'],
#   ['slr1609'],
#   ['slr1041'],
#   ['slr1042', 'slr1043'],
#   ['mcpA'],
#   ['slr1045', 'slr1046'],
#   ['pleD'],
#   ['slr1048'],
#   ['sll1011'],
#   ['rps32'],
#   ['slr1050'],
#   ['envM', 'slr1052'],
#   ['slr1053'],
#   ['frpC'],
#   ['chlH'],
#   ['slr1056'],
#   ['sll1006'],
#   ['mazG'],
#   ['sll1004'],
#   ['sll1003'],
#   ['ssl1923'],
#   ['ssl1922', 'ssl1920'],
#   ['ycf22'],
#   ['sll1001', 'ssl1918'],
#   ['slr1753'],
#   ['gpsA'],
#   ['sll1647'],
#   ['glnA'],
#   ['slr1759', 'slr1760', 'ytfC'],
#   ['sll1643'],
#   ['slr1762'],
#   ['slr1763'],
#   ['sll1642'],
#   ['capA'],
#   ['gad'],
#   ['ssr2962', 'slr1767'],
#   ['sll1640', 'ureD'],
#   ['sll1638'],
#   ['slr1768'],
#   ['fbp'],
#   ['slr1770'],
#   ['slr1771'],
#   ['dgt'],
#   ['psbK'],
#   ['sll1752'],
#   ['ssr3122'],
#   ['slr1846'],
#   ['slr1847', 'hisD'],
#   ['merA'],
#   ['sll1751'],
#   ['ureC', 'sll1749'],
#   ['ssl3342'],
#   ['slr1851'],
#   ['ssr3129'],
#   ['sll1946'],
#   ['ycf23'],
#   ['dxs'],
#   ['rub'],
#   ['ycf48'],
#   ['psbE', 'psbF', 'psbL', 'psbJ'],
#   ['proB'],
#   ['ssr3452'],
#   ['slr2036'],
#   ['slr2037', 'slr2038'],
#   ['sll1942', 'gyrA'],
#   ['divK', 'slr2042'],
#   ['sll1940', 'sll1939'],
#   ['ssr3465'],
#   ['sll1938'],
#   ['fur'],
#   ['zntC', 'slr2044', 'slr2045'],
#   ['ssr3467'],
#   ['slr2046'],
#   ['phoH'],
#   ['slr2048'],
#   ['slr2049'],
#   ['cpcG1'],
#   ['slr2052'],
#   ['sll1934'],
#   ['slr2053'],
#   ['dnaJ'],
#   ['dnaK'],
#   ['gylA'],
#   ['sll1930'],
#   ['comE'],
#   ['slr1906', 'slr1907'],
#   ['slr1908'],
#   ['slr1909'],
#   ['amiA', 'slr1911'],
#   ['sll1837'],
#   ['slr1912'],
#   ['slr1913', 'slr1914'],
#   ['sll1835'],
#   ['sll1834'],
#   ['slr1915'],
#   ['slr1916'],
#   ['slr1917'],
#   ['slr1918'],
#   ['ftsI', 'sll1832'],
#   ['glcF'],
#   ['sll1830'],
#   ['slr1919'],
#   ['slr1920'],
#   ['sll0998'],
#   ['ssl1911'],
#   ['slr1019'],
#   ['sll0997', 'sll0996'],
#   ['sqdB'],
#   ['ssr1698'],
#   ['sll0995'],
#   ['sll0994', 'sll0993'],
#   ['argD'],
#   ['slr1023', 'slr1024', 'slr1025'],
#   ['sll0992', 'sll0990'],
#   ['slr1028'],
#   ['chlI', 'tyrS'],
#   ['slr1032', 'slr1033'],
#   ['tyrS'],
#   ['slr1034'],
#   ['slr1035'],
#   ['sll0986'],
#   ['sll0985', 'sll0984'],
#   ['slr1037'],
#   ['sll0983'],
#   ['sll0982'],
#   ['sll0981', 'sll0980'],
#   ['slr1039'],
#   ['slr1376', 'lepB', 'slr1378'],
#   ['cydA', 'cydB'],
#   ['trmB'],
#   ['ackA', 'clcD'],
#   ['ssr2315'],
#   ['slr1383', 'ssr2317', 'slr1384'],
#   ['slr1385'],
#   ['ssr2318'],
#   ['pobA', 'ssl2559'],
#   ['sll1296'],
#   ['pilJ'],
#   ['sll1293', 'sll1292'],
#   ['sll1291'],
#   ['rnb'],
#   ['sll1289'],
#   ['ftsH', 'slr1391'],
#   ['ssr2333', 'feoB'],
#   ['hliA'],
#   ['slr1393'],
#   ['slr1394'],
#   ['sll1286'],
#   ['slr1395'],
#   ['slr1396'],
#   ['slr1397'],
#   ['slr1398'],
#   ['cofG', 'sll1284', 'spoIID'],
#   ['slr1699'],
#   ['sll1584'],
#   ['lig'],
#   ['sll1582'],
#   ['gumB'],
#   ['ssr2843', 'slr1702'],
#   ['serS'],
#   ['cpcD'],
#   ['cpcC', 'cpcC'],
#   ['cpcA'],
#   ['cpcB'],
#   ['ssr2848'],
#   ['slr1704'],
#   ['sll1575', 'sll1574'],
#   ['sll1573'],
#   ['aspA'],
#   ['dfrA'],
#   ['ssr2857'],
#   ['slr1708'],
#   ['dnaE'],
#   ['sll1571'],
#   ['sll1570'],
#   ['mrcB'],
#   ['sll1568'],
#   ['sll1927'],
#   ['sll1926'],
#   ['slr2005'],
#   ['sll1925'],
#   ['mrpC', 'ndhD5'],
#   ['mrpC'],
#   ['ndhD6', 'slr2010', 'ssr3409', 'ssr3410', 'slr2011', 'mrpB'],
#   ['slr2013'],
#   ['sll1924'],
#   ['slr2015', 'slr2016', 'slr2017'],
#   ['slr2018'],
#   ['slr2019'],
#   ['sll1921'],
#   ['sll1920'],
#   ['fabD'],
#   ['slr2024'],
#   ['slr2025'],
#   ['hemN', 'nadD', 'sll1915'],
#   ['folP', 'slr2027'],
#   ['sll1913'],
#   ['sll1912', 'ssl3615'],
#   ['sll1911'],
#   ['zam'],
#   ['slr2030'],
#   ['slr2031'],
#   ['argH', 'slr1134'],
#   ['slr1135'],
#   ['sll1084'],
#   ['ctaC'],
#   ['ctaD'],
#   ['ctaE'],
#   ['trxA'],
#   ['slr1140'],
#   ['nrtD'],
#   ['sll1081'],
#   ['sll1080'],
#   ['hypB'],
#   ['sll1078'],
#   ['speB'],
#   ['slr1142'],
#   ['slr1143'],
#   ['ziaA'],
#   ['leuS'],
#   ['gltS'],
#   ['sml0011'],
#   ['slr1147'],
#   ['slr1148'],
#   ['slr1149'],
#   ['slr1150'],
#   ['sll1072', 'sll1071'],
#   ['tktA'],
#   ['fabF'],
#   ['acpP'],
#   ['sll1068', 'ssl3451'],
#   ['bfr'],
#   ['sll1825'],
#   ['rpl25', 'purA'],
#   ['ssl3446'],
#   ['rpl31'],
#   ['rps9', 'rpl13'],
#   ['truA', 'rpl17'],
#   ['rpoA'],
#   ['rps11', 'rps13'],
#   ['rpl36'],
#   ['infA'],
#   ['adk'],
#   ['secY'],
#   ['rpl15'],
#   ['rps5', 'rpl18', 'rpl6'],
#   ['rps8'],
#   ['rpl5'],
#   ['rpl24',
#    'rpl14',
#    'rps17',
#    'rpl29',
#    'rpl16',
#    'rps3',
#    'rpl22',
#    'rps19',
#    'rpl2'],
#   ['rpl23', 'rpl4', 'rpl3'],
#   ['slr1894'],
#   ['ycf21'],
#   ['slr1895'],
#   ['slr1896'],
#   ['petJ'],
#   ['srrA'],
#   ['argB'],
#   ['ureF'],
#   ['slr1900'],
#   ['slr1901'],
#   ['slr1902', 'slr1903'],
#   ['sll1792', 'sll1791'],
#   ['rpoC2'],
#   ['rpoB'],
#   ['sll1786'],
#   ['rps20'],
#   ['sll1124', 'sll1123'],
#   ['sll1121'],
#   ['sll1120'],
#   ['sll1119'],
#   ['slr1194'],
#   ['slr1195', 'slr1196', 'slr1197'],
#   ['sll1118'],
#   ['ssr2009'],
#   ['slr1198'],
#   ['mutL'],
#   ['livH'],
#   ['slr1201'],
#   ['lacF'],
#   ['slr1203'],
#   ['htrA'],
#   ['slr1205'],
#   ['slr1206'],
#   ['slr1207'],
#   ['ssr2016'],
#   ['slr1208', 'slr1209', 'slr1210', 'cobN'],
#   ['ETR1', 'slr1213'],
#   ['slr1214'],
#   ['slr1215'],
#   ['aroQ'],
#   ['mgtE'],
#   ['sll1971'],
#   ['slr2070'],
#   ['slr2071'],
#   ['sll1969', 'pmgA'],
#   ['sll1967'],
#   ['ilvA'],
#   ['slr2073'],
#   ['manA'],
#   ['sll1965'],
#   ['groES'],
#   ['groEL'],
#   ['slr2077'],
#   ['slr2078'],
#   ['ssl3712'],
#   ['aroC'],
#   ['rpl12'],
#   ['rpl10'],
#   ['rpl1'],
#   ['rpl11'],
#   ['nusG'],
#   ['secE'],
#   ['rpl19'],
#   ['slr1826'],
#   ['slr1827'],
#   ['sll1739'],
#   ['sll1738'],
#   ['sll1737'],
#   ['petF'],
#   ['slr1829'],
#   ['phbC'],
#   ['sll1736'],
#   ['sll1735'],
#   ['sll1734'],
#   ['ndhD3'],
#   ['ndhF3'],
#   ['sll1730'],
#   ['psaA'],
#   ['psaB'],
#   ['sll1726', 'sll1725'],
#   ['icsA', 'sll1723', 'sll1722'],
#   ['slr1837'],
#   ['pdhB'],
#   ['ccmK'],
#   ['ccmK'],
#   ['slr1840'],
#   ['slr1841'],
#   ['cysK'],
#   ['zwf'],
#   ['uvrA'],
#   ['sll1717'],
#   ['sll1716'],
#   ['sll1715', 'sll1714'],
#   ['hisC', 'hupA'],
#   ['sll1469'],
#   ['slr1535'],
#   ['recQ'],
#   ['slr1537'],
#   ['cbiD'],
#   ['slr1540'],
#   ['slr1541'],
#   ['ispF'],
#   ['slr1543'],
#   ['bhy'],
#   ['ssr2595', 'slr1544'],
#   ['rpoE'],
#   ['slr1546', 'slr1547'],
#   ['sll1466', 'ssl2823'],
#   ['sll1464'],
#   ['ftsH'],
#   ['hypE', 'sll1461'],
#   ['surE'],
#   ['def'],
#   ['ssr2611'],
#   ['lysS'],
#   ['rfbJ'],
#   ['sll1456'],
#   ['slr1552'],
#   ['sll1455'],
#   ['narB'],
#   ['nrtD'],
#   ['nrtC'],
#   ['nrtB'],
#   ['nrtA'],
#   ['sll1634'],
#   ['slr1748'],
#   ['repA'],
#   ['ftsZ'],
#   ['sll1632'],
#   ['prc', 'slr1752'],
#   ['mraW'],
#   ['slr1218', 'ureE'],
#   ['slr1220'],
#   ['slr1222'],
#   ['uvrD'],
#   ['sll1142'],
#   ['sulA'],
#   ['malK'],
#   ['pknA'],
#   ['sll1138'],
#   ['purC'],
#   ['IAP75'],
#   ['prfC', 'slr1229'],
#   ['slr1230'],
#   ['sll1135'],
#   ['slr1232'],
#   ['ssr2047'],
#   ['frdA'],
#   ['ssr2049'],
#   ['slr1234', 'slr1235', 'slr1236'],
#   ['ssl2250'],
#   ['sll1132', 'sll1131'],
#   ['codA'],
#   ['sll1130', 'ssl2245'],
#   ['todF'],
#   ['ssr2060'],
#   ['grxC'],
#   ['gshB'],
#   ['ssr2062'],
#   ['menB'],
#   ['pntA', 'slr1240', 'slr1241'],
#   ['ssr2067', 'pntB'],
#   ['pmbA'],
#   ['slr1436'],
#   ['slr1437', 'slr1438'],
#   ['ileS'],
#   ['ssr2406'],
#   ['dnaX'],
#   ['slr1440'],
#   ['sll1359', 'sll1358'],
#   ['glgP'],
#   ['slr1441'],
#   ['sll1355'],
#   ['slr1442', 'pknA'],
#   ['slr1444'],
#   ['ssr2422'],
#   ['recJ', 'sll1353', 'sll1352'],
#   ['cscK'],
#   ['slr1449', 'slr1450'],
#   ['sll1350', 'cbbZp', 'sll1348'],
#   ['ribH'],
#   ['psbZ'],
#   ['sll1280'],
#   ['rps1'],
#   ['slr1357'],
#   ['recF', 'sll1276'],
#   ['pykF'],
#   ['slr1362'],
#   ['sll1274'],
#   ['slr1363'],
#   ['bioB', 'bioY', 'lspA'],
#   ['sll1273'],
#   ['sll1272'],
#   ['sll1271'],
#   ['glnHP'],
#   ['ssl2501'],
#   ['glgP'],
#   ['cobL'],
#   ['cdsA'],
#   ['sll1268'],
#   ['sll1267', 'sll1265'],
#   ['sll0877'],
#   ['mscL'],
#   ['ruvA', 'sll0875'],
#   ['slr0876'],
#   ['ssr1480'],
#   ['gatA'],
#   ['slr0878'],
#   ['gcvH'],
#   ['slr0880'],
#   ['napC'],
#   ['ssl1633'],
#   ['slr0881'],
#   ['sll0872'],
#   ['slr0882'],
#   ['psr'],
#   ['sll0871'],
#   ['gap1'],
#   ['slr0885'],
#   ['aat'],
#   ['lipA'],
#   ['sll0867'],
#   ['fabG', 'slr0887'],
#   ['slr0888', 'slr0889'],
#   ['ssr1499'],
#   ['slr0890'],
#   ['uvrC'],
#   ['amiA'],
#   ['sll0864'],
#   ['sll0863', 'sll0862'],
#   ['murQ'],
#   ['sll0860'],
#   ['petA'],
#   ['petC'],
#   ['psbH'],
#   ['psbN'],
#   ['hliB'],
#   ['sll1315'],
#   ['dctP'],
#   ['slr1403'],
#   ['sll1308'],
#   ['slr1406'],
#   ['slr1407'],
#   ['slr1409', 'slr1410'],
#   ['sll1307'],
#   ['sll1306', 'sll1305', 'sll1304', 'sll1785'],
#   ['sll1784', 'sll1783'],
#   ['slr1852', 'slr1853'],
#   ['slr1854', 'slr1855', 'slr1856', 'glgX'],
#   ['slr1859'],
#   ['ICFG', 'slr1861'],
#   ['slr1862', 'slr1864'],
#   ['slr1865', 'slr1866'],
#   ['trpD'],
#   ['deoC'],
#   ['sll1775'],
#   ['sll1774'],
#   ['slr1869'],
#   ['slr1870'],
#   ['sll1773'],
#   ['slr1871'],
#   ['mutS', 'sll1771'],
#   ['sll1770'],
#   ['sll1769', 'ssl3383', 'ssl3382'],
#   ['sll1768'],
#   ['ddlA'],
#   ['exoD'],
#   ['clpS'],
#   ['slr1876'],
#   ['rps6'],
#   ['hpcE'],
#   ['cpcE'],
#   ['aslB', 'sll1765'],
#   ['sll1764'],
#   ['sll1763'],
#   ['sll1762'],
#   ['cobI'],
#   ['sll1761', 'thrB'],
#   ['slr1880'],
#   ['glmM'],
#   ['ssr3184'],
#   ['livF'],
#   ['ribF'],
#   ['sll1757'],
#   ['ssr3188'],
#   ['ssl3364'],
#   ['trpS'],
#   ['ssr3189'],
#   ['slr1885'],
#   ['slr1886'],
#   ['sll1755'],
#   ['hemC'],
#   ['slr1888'],
#   ['pta'],
#   ['sll2015'],
#   ['sfsA'],
#   ['sll2013'],
#   ['rpoD'],
#   ['sll2011'],
#   ['murD'],
#   ['sll2009', 'sll2008'],
#   ['hupE'],
#   ['ispG'],
#   ['sll2007', 'sll2006'],
#   ['gyrB'],
#   ['ssl3829'],
#   ['psbY'],
#   ['slr2141'],
#   ['sll2003'],
#   ['cefD'],
#   ['sll2002'],
#   ['slr2144', 'mbpA'],
#   ['sll1710'],
#   ['gdh'],
#   ['ssl3291'],
#   ['sll1708'],
#   ['slr1805'],
#   ['csgA', 'sppA', 'sll1702'],
#   ['slr1807'],
#   ['hemA'],
#   ['slr1809'],
#   ['sll1699', 'sll1698'],
#   ['sll1697'],
#   ['slr1811'],
#   ['slr1812'],
#   ['slr1813'],
#   ['slr1814'],
#   ['slr1815', 'slr1816'],
#   ['sll1696', 'hofG'],
#   ['hofG'],
#   ['sll1693'],
#   ['slr1818'],
#   ['sll1692', 'sll1691'],
#   ['slr1819'],
#   ['rpoD2-V'],
#   ['thrC'],
#   ['slr1820'],
#   ['sll1687'],
#   ['slr1821', 'nth'],
#   ['slr1732'],
#   ['sll1631', 'sll1630', 'phr'],
#   ['sll1628'],
#   ['opcA'],
#   ['slr1735'],
#   ['lexA'],
#   ['sdhB'],
#   ['sll1624', 'sll1623'],
#   ['ubiA'],
#   ['slr1737'],
#   ['sll1621'],
#   ['slr1738'],
#   ['sll1620'],
#   ['slr1739'],
#   ['slr1740'],
#   ['sll1618'],
#   ['slr1742'],
#   ['ndh'],
#   ['amiA'],
#   ['murI'],
#   ['slr1747'],
#   ['ndh'],
#   ['slr0852', 'rimI'],
#   ['phr'],
#   ['sll0858', 'sll0857', 'rpoE'],
#   ['sll0855', 'sll0854'],
#   ['sll0853'],
#   ['slr0856', 'slr0857'],
#   ['psbC', 'psbD'],
#   ['dnaA'],
#   ['sll0847'],
#   ['purT'],
#   ['sll0846'],
#   ['lmbP'],
#   ['slr0863'],
#   ['mnmA'],
#   ['sll0843', 'nplT'],
#   ['slr0864'],
#   ['slr0865'],
#   ['sll0839', 'pyrF', 'sll0837'],
#   ['slr0867'],
#   ['slr0868'],
#   ['slr0869'],
#   ['slr0870', 'slr0871'],
#   ['slr0872'],
#   ['mutS'],
#   ['slr1243'],
#   ['sll1164', 'sll1163', 'sll1162'],
#   ['sll1161'],
#   ['sll1160', 'sll1159'],
#   ['sll1158'],
#   ['slr1245'],
#   ['ssr2078'],
#   ['slr1246'],
#   ['sll1157', 'sll1156'],
#   ['sll1155'],
#   ['norA'],
#   ['pstS'],
#   ['pstC', 'pstA'],
#   ['pstB'],
#   ['cyp'],
#   ['dcoH', 'sll1151'],
#   ['ssr2087'],
#   ['sll1150'],
#   ['slr1253'],
#   ...])

# %%
predict_operons('B_subtilis_168.ptt')
# Out:
# (2662,
#  [['dnaA'],
#   ['dnaN'],
#   ['yaaA', 'recF', 'yaaB'],
#   ['gyrB'],
#   ['gyrA'],
#   ['yaaC'],
#   ['guaB'],
#   ['dacA'],
#   ['yaaD', 'yaaE'],
#   ['serS'],
#   ['dck', 'dgk'],
#   ['yaaH'],
#   ['yaaI'],
#   ['tadA'],
#   ['dnaX', 'yaaK', 'recR', 'yaaL'],
#   ['bofA'],
#   ['csfB'],
#   ['xpaC', 'yaaN'],
#   ['yaaO', 'tmk'],
#   ['yaaQ', 'yaaR', 'holB', 'yaaT', 'yabA'],
#   ['yabB', 'yazA', 'yabC'],
#   ['abrB'],
#   ['metS'],
#   ['yabD'],
#   ['yabE'],
#   ['rnmV', 'ksgA'],
#   ['yabG'],
#   ['veg'],
#   ['sspF'],
#   ['ipk'],
#   ['purR', 'yabJ'],
#   ['spoVG'],
#   ['glmU', 'prs'],
#   ['ctc'],
#   ['pth'],
#   ['yabK'],
#   ['mfd'],
#   ['spoVT'],
#   ['yabM', 'yabN', 'yabO'],
#   ['yabP', 'yabQ', 'divIC'],
#   ['yabR'],
#   ['spoIIE'],
#   ['yabS', 'yabT'],
#   ['tilS', 'hprT'],
#   ['ftsH'],
#   ['coaX', 'hslO', 'yacD'],
#   ['cysK'],
#   ['pabB', 'pabA', 'pabC', 'sul', 'folB', 'folK', 'yazB', 'dusB'],
#   ['lysS'],
#   ['ctsR', 'mcsA', 'mcsB', 'clpC'],
#   ['radA', 'yacK'],
#   ['yacL', 'ispD', 'ispF'],
#   ['gltX'],
#   ['cysE', 'cysS', 'mrnC', 'rlmB', 'yacP'],
#   ['sigH'],
#   ['rpmG', 'secE'],
#   ['nusG'],
#   ['rplK'],
#   ['rplA'],
#   ['rplJ', 'rplL'],
#   ['ybxB'],
#   ['rpoB'],
#   ['rpoC'],
#   ['ybxF'],
#   ['rpsL', 'rpsG'],
#   ['fusA'],
#   ['tufA'],
#   ['ybaC'],
#   ['rpsJ', 'rplC', 'rplD', 'rplW', 'rplB'],
#   ['rpsS',
#    'rplV',
#    'rpsC',
#    'rplP',
#    'rpmC',
#    'rpsQ',
#    'rplN',
#    'rplX',
#    'rplE',
#    'rpsN',
#    'rpsH',
#    'rplF',
#    'rplR',
#    'rpsE',
#    'rpmD',
#    'rplO',
#    'secY'],
#   ['adk', 'mapA', 'ybzG', 'infA', 'rpmJ', 'rpsM', 'rpsK'],
#   ['rpoA'],
#   ['rplQ'],
#   ['cbiO', 'cbiO', 'ybaF', 'truA'],
#   ['rplM', 'rpsI'],
#   ['ybaJ'],
#   ['ybaK'],
#   ['cwlD'],
#   ['salA'],
#   ['gerD'],
#   ['kbaA'],
#   ['ybaN'],
#   ['ybaR'],
#   ['ybaS'],
#   ['ybbA', 'feuC', 'feuB', 'feuA'],
#   ['ybbB'],
#   ['ybbC', 'ybbD', 'ybbE'],
#   ['ybbF', 'ybbH', 'murQ'],
#   ['ybbJ', 'ybbK'],
#   ['sigW', 'rsiW'],
#   ['ybbP', 'ybbR', 'glmM'],
#   ['glmS'],
#   ['alkA'],
#   ['adaA', 'adaB'],
#   ['ndhF', 'ybcC'],
#   ['ybcF'],
#   ['ybcH'],
#   ['ybcI'],
#   ['ybzH'],
#   ['ybcL'],
#   ['ybcM'],
#   ['skfA'],
#   ['skfB', 'skfC', 'skfE'],
#   ['skfF', 'skfG', 'skfH'],
#   ['ybdG', 'ybdJ', 'ybdK'],
#   ['ybzI'],
#   ['ybdM'],
#   ['ybdN'],
#   ['ybdO'],
#   ['ybxG'],
#   ['csgA', 'ybxH'],
#   ['ybxI'],
#   ['cypC'],
#   ['ybyB'],
#   ['ybeC'],
#   ['glpQ'],
#   ['glpT'],
#   ['ybeF'],
#   ['ybfA', 'ybfB'],
#   ['ybfE'],
#   ['ybfF'],
#   ['ybfG'],
#   ['ybfH', 'ybfI'],
#   ['purT'],
#   ['mpr', 'ybfJ'],
#   ['ybfK'],
#   ['pssA', 'ybfM', 'psd'],
#   ['ybfN'],
#   ['ybfO'],
#   ['ybfP'],
#   ['ybfQ'],
#   ['gltP'],
#   ['nagP', 'nagBB'],
#   ['ybgA', 'ybgB'],
#   ['ybgE'],
#   ['ybgF'],
#   ['mmuM'],
#   ['glnT', 'ybgJ'],
#   ['glnJ', 'glnL'],
#   ['ycbC', 'ycbD'],
#   ['gudP', 'gudD'],
#   ['ycbG'],
#   ['garD'],
#   ['ycbJ'],
#   ['rtpA', 'ycbK'],
#   ['ycbL', 'ycbM'],
#   ['ycbN', 'ycbO'],
#   ['ycbP'],
#   ['cwlJ'],
#   ['ycbR'],
#   ['yczK', 'phoD', 'tatAD'],
#   ['tatCD'],
#   ['pcp'],
#   ['ycbU'],
#   ['lmrB', 'lmrA'],
#   ['ansZ'],
#   ['estA'],
#   ['yczC'],
#   ['yccF'],
#   ['natK', 'natR'],
#   ['natA', 'natB'],
#   ['yccK'],
#   ['ycdA'],
#   ['ycdB'],
#   ['ycdC'],
#   ['cwlK'],
#   ['rapJ'],
#   ['ycdF', 'ycdG'],
#   ['adcA'],
#   ['adcC', 'adcB'],
#   ['yceB'],
#   ['yceC', 'yceD', 'yceE'],
#   ['yceF'],
#   ['yceG', 'yceH'],
#   ['yceI'],
#   ['yceJ'],
#   ['yceK'],
#   ['opuAA', 'opuAB', 'opuAC'],
#   ['amhX'],
#   ['ycgA'],
#   ['ycgB'],
#   ['amyE'],
#   ['ldh', 'lctP'],
#   ['mdr'],
#   ['ycgE'],
#   ['ycgF'],
#   ['ycgG'],
#   ['ycgH'],
#   ['ycgI'],
#   ['nadE'],
#   ['tmrB'],
#   ['aroK'],
#   ['ycgJ'],
#   ['ycgK'],
#   ['cah'],
#   ['ycgL'],
#   ['ycgM', 'ycgN'],
#   ['ycgO'],
#   ['ycgP'],
#   ['ycgQ', 'ycgR'],
#   ['ycgS'],
#   ['ycgT'],
#   ['nasF'],
#   ['nasE', 'nasD'],
#   ['nasC', 'nasB'],
#   ['nasA'],
#   ['yciA', 'yciB'],
#   ['yczL', 'yciC'],
#   ['yckA', 'yckB'],
#   ['yckC'],
#   ['yckD'],
#   ['bglC'],
#   ['nin', 'nucA'],
#   ['tlpC'],
#   ['hxlB', 'hxlA'],
#   ['hxlR'],
#   ['srfAA', 'srfAB', 'comS'],
#   ['srfAC', 'srfAD'],
#   ['ycxA'],
#   ['ycxB'],
#   ['ycxC'],
#   ['ycxD'],
#   ['yczE'],
#   ['tcyC', 'tcyB', 'tcyA'],
#   ['yclA'],
#   ['yclB', 'ubiD', 'bsdD', 'yclD'],
#   ['yclE'],
#   ['dtpT'],
#   ['yclG'],
#   ['yczF'],
#   ['gerKA', 'gerKC', 'gerKB'],
#   ['yclH', 'yclI'],
#   ['yclJ', 'yclK'],
#   ['rapC', 'phrC'],
#   ['yczN'],
#   ['yclM'],
#   ['yclN', 'yclO', 'yclP', 'yclQ'],
#   ['ycnB', 'ycnC'],
#   ['ycnD', 'ycnE'],
#   ['yczG'],
#   ['gabR'],
#   ['gabT'],
#   ['gabD'],
#   ['glcU', 'gdh'],
#   ['ycnI', 'ycnJ', 'ycnK'],
#   ['ycnL'],
#   ['mtlA', 'mtlF', 'mtlD'],
#   ['ycsA'],
#   ['sipU'],
#   ['yczH'],
#   ['ycsD'],
#   ['yczO'],
#   ['ycsE'],
#   ['ycsF', 'ycsG', 'ycsI', 'kipI', 'kipA', 'kipR'],
#   ['lipC'],
#   ['yczI'],
#   ['yczJ'],
#   ['pbpC'],
#   ['ycsN'],
#   ['mtlR'],
#   ['ydaB'],
#   ['ydaC'],
#   ['ydaD', 'ydaE'],
#   ['ydaF'],
#   ['ydaG'],
#   ['ydaH'],
#   ['ydzA'],
#   ['lrpC'],
#   ['topB'],
#   ['ydaJ', 'ydaK', 'ydaL', 'ydaM', 'ydaN'],
#   ['ydaO'],
#   ['mutT'],
#   ['ydaP'],
#   ['ydzK'],
#   ['mntH'],
#   ['ydaS'],
#   ['ydaT'],
#   ['ydbA'],
#   ['gsiB'],
#   ['ydbB', 'ydbC'],
#   ['ydbD'],
#   ['dctB'],
#   ['dctS', 'dctR'],
#   ['dctP'],
#   ['ydbI'],
#   ['ydbJ', 'ydbK'],
#   ['ydbL'],
#   ['ydbM'],
#   ['ydbN'],
#   ['ydbO'],
#   ['ydbP'],
#   ['ddl'],
#   ['murF'],
#   ['cshA'],
#   ['ydbS', 'ydbT'],
#   ['ydcA'],
#   ['acpS'],
#   ['ydcC'],
#   ['alrA'],
#   ['endB', 'ndoA'],
#   ['rsbRA', 'rsbS', 'rsbT', 'rsbU'],
#   ['rsbV', 'rsbW', 'sigB', 'rsbX'],
#   ['ydcF', 'ydcG', 'ydcH'],
#   ['ydcI'],
#   ['ydcK'],
#   ['ydcL', 'immA', 'immR'],
#   ['sacV', 'ydzL'],
#   ['ydcO'],
#   ['ydcP', 'ydcQ', 'ydcR'],
#   ['ydcS',
#    'ydcT',
#    'yddA',
#    'yddB',
#    'yddC',
#    'yddD',
#    'yddE',
#    'yddF',
#    'yddG',
#    'yddH',
#    'yddI'],
#   ['yddJ'],
#   ['yddK'],
#   ['rapI', 'phrI'],
#   ['yddM'],
#   ['yddN'],
#   ['lrpA'],
#   ['lrpB'],
#   ['yddQ'],
#   ['yddR'],
#   ['yddS'],
#   ['ydzM', 'yddT'],
#   ['ydzN'],
#   ['ydeA'],
#   ['cspC'],
#   ['ydeB'],
#   ['ydzE'],
#   ['ydeC'],
#   ['ydeD'],
#   ['ydeE'],
#   ['ydeF'],
#   ['ydeG'],
#   ['ydeH'],
#   ['ydeI'],
#   ['ydeJ'],
#   ['ydeK'],
#   ['ydeL'],
#   ['ydeM'],
#   ['ydeN'],
#   ['ydzF'],
#   ['ydeO'],
#   ['ydeP'],
#   ['ydeQ'],
#   ['ydeR'],
#   ['ydeS'],
#   ['ydzO'],
#   ['aseR', 'ydfA'],
#   ['ydfB'],
#   ['ydfC'],
#   ['ydfD'],
#   ['ydfE'],
#   ['ydfF'],
#   ['ydfG'],
#   ['ydzP', 'ydzQ'],
#   ['ydfH', 'ydfI'],
#   ['ydfJ'],
#   ['nap'],
#   ['ydfK'],
#   ['ydfL'],
#   ['ydfM'],
#   ['ydfN', 'ydfO'],
#   ['ydfP'],
#   ['ydfQ'],
#   ['ydzH'],
#   ['ydzR'],
#   ['ydfR'],
#   ['ydfS'],
#   ['cotP', 'ydgA', 'ydgB'],
#   ['ydgC', 'ydgD'],
#   ['ydgE'],
#   ['vmlR'],
#   ['ydgF'],
#   ['dinB'],
#   ['ydgG', 'ydgH'],
#   ['ydgI', 'ydgJ'],
#   ['ydgK'],
#   ['ydhB'],
#   ['ydhC'],
#   ['ydhD'],
#   ['ydhE'],
#   ['ydhF'],
#   ['phoB'],
#   ['ydhG'],
#   ['ydhH', 'ydhI'],
#   ['ydhJ'],
#   ['ydhK'],
#   ['pbuE'],
#   ['gmuB', 'gmuA', 'gmuC', 'gmuD'],
#   ['gmuR', 'gmuE', 'gmuF', 'gmuG'],
#   ['thiL', 'ydiB', 'ydiC', 'rimI', 'gcp'],
#   ['ydiF'],
#   ['moaC', 'ydiH', 'tatAY', 'tatCY'],
#   ['ydiK', 'ydiL'],
#   ['groES', 'groEL'],
#   ['ydiM'],
#   ['ydzU'],
#   ['ydiO', 'ydiP'],
#   ['ydiR', 'ydiS', 'ydjA'],
#   ['ydjB'],
#   ['ydjC'],
#   ['gutR'],
#   ['gutB'],
#   ['gutP'],
#   ['ydjE'],
#   ['pspA'],
#   ['ydjG', 'ydjH', 'ydjI'],
#   ['ydjJ'],
#   ['iolT'],
#   ['bdhA'],
#   ['ydjM'],
#   ['ydjN'],
#   ['ydzJ'],
#   ['ydjO'],
#   ['ydjP', 'yeaA'],
#   ['cotA'],
#   ['gabP', 'ydzX'],
#   ['yeaB'],
#   ['yeaC', 'yeaD', 'yebA'],
#   ['guaA'],
#   ['pbuG'],
#   ['yebC'],
#   ['yebD'],
#   ['yebE', 'yebG'],
#   ['purE', 'purK', 'purB'],
#   ['purC', 'purS', 'purQ', 'purL', 'purF'],
#   ['purM', 'purN', 'purH', 'purD'],
#   ['yezC'],
#   ['yecA'],
#   ['yezF'],
#   ['yerA', 'yerB', 'yerC'],
#   ['yerD'],
#   ['pcrB'],
#   ['pcrA', 'ligA', 'yerH'],
#   ['yerI'],
#   ['sapB'],
#   ['opuE'],
#   ['gatC', 'gatA', 'gatB'],
#   ['yerO'],
#   ['swrC'],
#   ['yerQ'],
#   ['yefA'],
#   ['yefB'],
#   ['yefC'],
#   ['yeeA', 'yeeB'],
#   ['yeeC'],
#   ['yeeD'],
#   ['yezA'],
#   ['yezG', 'yeeF'],
#   ['yeeG'],
#   ['rapH', 'phrH'],
#   ['yeeI'],
#   ['yeeK'],
#   ['yezE'],
#   ['yesE', 'yesF'],
#   ['cotJA', 'cotJB', 'cotJC'],
#   ['yesJ', 'yesK'],
#   ['yesL', 'yesM', 'yesN'],
#   ['yesO', 'yesP', 'yesQ', 'yesR', 'yesS', 'rhgT', 'yesU', 'yesV'],
#   ['yesW', 'yesX'],
#   ['yesY', 'yesZ', 'yetA'],
#   ['lplA'],
#   ['lplB', 'lplC', 'lplD'],
#   ['yetF'],
#   ['yetG'],
#   ['yetH'],
#   ['yezD'],
#   ['yetJ', 'yetK'],
#   ['yetL'],
#   ['yetM'],
#   ['yetN'],
#   ['yetO'],
#   ['ltaSA'],
#   ['yfnH'],
#   ['yfnG', 'yfnF', 'yfnE', 'yfnD'],
#   ['yfnC'],
#   ['yfnB'],
#   ['yfnA'],
#   ['yfmT', 'yfmS'],
#   ['yfmR'],
#   ['yfmQ'],
#   ['yfmP'],
#   ['yfmO'],
#   ['yfmN'],
#   ['yfmM'],
#   ['yfmL'],
#   ['yfmK'],
#   ['yfmJ'],
#   ['yfmI'],
#   ['yfmG'],
#   ['yfmF', 'yfmE', 'yfmD'],
#   ['yfmC'],
#   ['yfmB'],
#   ['yfmA', 'yflT'],
#   ['pel'],
#   ['yflS'],
#   ['citS', 'citT', 'yflP'],
#   ['citM'],
#   ['yflN'],
#   ['nosA'],
#   ['yflL'],
#   ['yflK'],
#   ['yflJ'],
#   ['yflI'],
#   ['yflH'],
#   ['yflG'],
#   ['nagP'],
#   ['yflE'],
#   ['yflD', 'yflB'],
#   ['yflA'],
#   ['yfkT', 'yfkS', 'yfkR', 'yfkQ'],
#   ['treP'],
#   ['treA', 'treR'],
#   ['yfkO'],
#   ['yfkN'],
#   ['yfkM'],
#   ['yfkL'],
#   ['yfkK'],
#   ['yfkJ', 'yfkI', 'yfkH'],
#   ['yfkF'],
#   ['yfkE'],
#   ['yfkD'],
#   ['yfkC', 'yfkA'],
#   ['yfjT'],
#   ['pdaA'],
#   ['yfjR'],
#   ['yfjQ'],
#   ['yfjP'],
#   ['yfjO'],
#   ['yfzA'],
#   ['dusC'],
#   ['yfjM', 'yfjL'],
#   ['acoA', 'acoB', 'acoC', 'acoL'],
#   ['acoR'],
#   ['sspH'],
#   ['yfjF'],
#   ['yfjE'],
#   ['yfjD', 'yfjC', 'yfjB', 'yfjA'],
#   ['malA'],
#   ['malR', 'malP'],
#   ['malQ', 'yfiC'],
#   ['catD', 'catE'],
#   ['yfiF'],
#   ['yfiG', 'yfiH', 'yfiI'],
#   ['yfiJ', 'yfiK'],
#   ['yfiL', 'yfiM', 'yfiN'],
#   ['padR'],
#   ['estB'],
#   ['yfiQ'],
#   ['yfiR', 'yfiS'],
#   ['yfiT'],
#   ['yfiU'],
#   ['yfiV'],
#   ['mprF'],
#   ['yfiY'],
#   ['yfiZ', 'yfhA'],
#   ['yfhB'],
#   ['yfhC'],
#   ['yfhD'],
#   ['yfhE'],
#   ['yfhF'],
#   ['recX', 'yfhH'],
#   ['yfhI'],
#   ['sspK'],
#   ['yfhJ'],
#   ['yfhK'],
#   ['yfhL', 'yfhM'],
#   ['csbB'],
#   ['yfhO'],
#   ['yfhP'],
#   ['yfhQ'],
#   ['yfhS'],
#   ['fabL'],
#   ['sspE'],
#   ['ygaB'],
#   ['ygaC'],
#   ['ygaD'],
#   ['ygaE'],
#   ['gsaB'],
#   ['ygaF'],
#   ['perR'],
#   ['ygzB'],
#   ['ygxA'],
#   ['spo0M'],
#   ['ygzA'],
#   ['ygzC'],
#   ['ygaJ'],
#   ['thiC'],
#   ['ygaK'],
#   ['senS'],
#   ['katA'],
#   ['ssuB', 'ssuA', 'ssuC', 'ssuD'],
#   ['ygaN'],
#   ['rpsN'],
#   ['ygaO', 'ygzD'],
#   ['yhzB'],
#   ['yhbA'],
#   ['yhbB', 'cspR'],
#   ['yhbD', 'yhbE', 'yhbF'],
#   ['prkA'],
#   ['yhbH'],
#   ['yhbI',
#    'yhbJ',
#    'yhcA',
#    'yhcB',
#    'yhcC',
#    'yhcD',
#    'yhcE',
#    'yhcF',
#    'yhcG',
#    'yhcH',
#    'yhcI'],
#   ['cspB'],
#   ['yhcJ'],
#   ['yhcK'],
#   ['tcyP'],
#   ['yhcM'],
#   ['yhcN'],
#   ['yhcO'],
#   ['yhcQ'],
#   ['yhcR', 'yhcS'],
#   ['yhcT'],
#   ['yhcU'],
#   ['yhcV'],
#   ['yhcW', 'yhcX'],
#   ['yhxA', 'glpP'],
#   ['glpF', 'glpK'],
#   ['glpD'],
#   ['pgcA'],
#   ['yhcY', 'yhcZ', 'yhdA'],
#   ['yhdB'],
#   ['yhdC'],
#   ['lytF'],
#   ['nsrR'],
#   ['ygxB'],
#   ['spoVR'],
#   ['phoA'],
#   ['lytE'],
#   ['citR'],
#   ['citA'],
#   ['yhdF'],
#   ['ctrA'],
#   ['yhdH'],
#   ['yhdI'],
#   ['yhdJ'],
#   ['yhdK', 'yhdL', 'sigM'],
#   ['yhdN'],
#   ['plsC'],
#   ['yhdP'],
#   ['cueR'],
#   ['yhdR'],
#   ['yhdT'],
#   ['crcBA', 'yhdV', 'yhdW'],
#   ['yhdX'],
#   ['yhdY'],
#   ['yhdZ'],
#   ['yheN'],
#   ['dat'],
#   ['nhaC'],
#   ['nhaX'],
#   ['yheJ'],
#   ['yheI', 'yheH'],
#   ['yheG', 'yheF'],
#   ['sspB'],
#   ['yheE'],
#   ['yheD', 'yheC'],
#   ['yheB'],
#   ['yheA'],
#   ['yhaZ'],
#   ['yhaX'],
#   ['hemZ'],
#   ['yhaU', 'khtT'],
#   ['khtS'],
#   ['yhaR'],
#   ['yhzD'],
#   ['natA', 'natB'],
#   ['yhaO', 'yhaN'],
#   ['yhaM'],
#   ['yhaL'],
#   ['prsA'],
#   ['yhzE'],
#   ['yhaJ'],
#   ['yhaI'],
#   ['hpr'],
#   ['yhaH'],
#   ['yhzF'],
#   ['trpP'],
#   ['serC'],
#   ['hinT'],
#   ['ecsA', 'ecsB', 'ecsC'],
#   ['yhaA'],
#   ['yhfA'],
#   ['yhgB', 'yhgC'],
#   ['pbpF'],
#   ['hemE'],
#   ['hemH', 'hemY'],
#   ['yhgD'],
#   ['yhgE'],
#   ['fabHB'],
#   ['yhfC'],
#   ['yhfE', 'yhfF'],
#   ['gltT'],
#   ['yhfH'],
#   ['yhfI', 'yhfJ'],
#   ['yhfK'],
#   ['yhfL'],
#   ['yhfM'],
#   ['yhfN'],
#   ['aprE'],
#   ['yhfO'],
#   ['yhfP'],
#   ['yhfQ'],
#   ['phoE'],
#   ['yhfS', 'yhfT', 'bioY'],
#   ['hemAT'],
#   ['yhfW'],
#   ['yhxC'],
#   ['yhzC'],
#   ['comK'],
#   ['yhxD'],
#   ['yhjA'],
#   ['yhjB', 'yhjC'],
#   ['yhjD'],
#   ['yhjE', 'sipV'],
#   ['yhjG'],
#   ['yhjH'],
#   ['glcP'],
#   ['ntdC', 'ntdB', 'ntdA'],
#   ['yhjM'],
#   ['yhjN'],
#   ['yhjO'],
#   ['yhjP'],
#   ['yhjQ'],
#   ['yhjR'],
#   ['addB', 'addA'],
#   ['sbcD', 'sbcC', 'yisB'],
#   ['gerPF', 'gerPE', 'gerPD', 'gerPC', 'gerPB', 'gerPA'],
#   ['yisI'],
#   ['yisJ'],
#   ['yisK'],
#   ['yisL'],
#   ['wprA'],
#   ['yisN'],
#   ['asnO'],
#   ['yizA'],
#   ['yisP'],
#   ['yisQ'],
#   ['yisR', 'degA'],
#   ['yisS'],
#   ['yisT'],
#   ['yisU'],
#   ['yisV'],
#   ['yisX'],
#   ['yisY'],
#   ['yisZ', 'sat'],
#   ['yitB'],
#   ['yitC', 'yitD'],
#   ['yitE'],
#   ['yitF', 'yitG'],
#   ['yitH', 'yitI'],
#   ['yitJ'],
#   ['yitK'],
#   ['yitL'],
#   ['yitM', 'yitO', 'yitP'],
#   ['yizB', 'yitQ', 'yitR'],
#   ['nprB'],
#   ['yitS'],
#   ['yitT'],
#   ['ipi'],
#   ['yizC'],
#   ['yitU'],
#   ['yitV'],
#   ['yitW'],
#   ['yitY', 'yitZ'],
#   ['argC', 'argJ', 'argB', 'argD'],
#   ['carA', 'carB', 'argF'],
#   ['yjzC'],
#   ['yjzD'],
#   ['yjaU'],
#   ['yjaV'],
#   ['med', 'comZ'],
#   ['yjzB'],
#   ['fabHA', 'fabF'],
#   ['yjaZ'],
#   ['appD', 'appF'],
#   ['appB', 'appC'],
#   ['yjbA'],
#   ['trpS'],
#   ['oppA'],
#   ['oppB', 'oppC', 'oppD', 'oppF'],
#   ['yjbB'],
#   ['yjbC'],
#   ['spxA'],
#   ['yjbE'],
#   ['mecA'],
#   ['coiA', 'pepF'],
#   ['yizD'],
#   ['yjbH', 'yjbI'],
#   ['yjbJ'],
#   ['yjbK'],
#   ['yjbL', 'yjbM', 'ppnK'],
#   ['yjbO'],
#   ['yjbP'],
#   ['yjbQ'],
#   ['tenA', 'tenI', 'thiO', 'thiS', 'thiG', 'thiF', 'yjbV'],
#   ['fabI'],
#   ['cotO'],
#   ['cotZ'],
#   ['cotY'],
#   ['cotX'],
#   ['cotW', 'cotV'],
#   ['yjcA'],
#   ['yjzK'],
#   ['yjcZ'],
#   ['spoVIF'],
#   ['yjcD'],
#   ['yjzE'],
#   ['yjcF', 'yjcG', 'yjcH'],
#   ['yjcI', 'yjcJ'],
#   ['yjcK'],
#   ['yjcL'],
#   ['yjcM'],
#   ['yjcN'],
#   ['yjzF', 'yjzG', 'yjcO'],
#   ['yjcP', 'yjcQ'],
#   ['yjcR'],
#   ['yjcS'],
#   ['yjdA'],
#   ['yjdB'],
#   ['manR'],
#   ['manP', 'manA'],
#   ['yjdF'],
#   ['yjdG'],
#   ['yjdH'],
#   ['yjdI'],
#   ['yjzH'],
#   ['yjdJ'],
#   ['ctaO'],
#   ['cotT'],
#   ['yjeA'],
#   ['yjfA'],
#   ['yjfB'],
#   ['yjfC'],
#   ['yjgA'],
#   ['yjgB'],
#   ['yjgC', 'yjgD'],
#   ['yjhA'],
#   ['yjhB'],
#   ['yjiA'],
#   ['yjiB', 'yjiC'],
#   ['yjzI'],
#   ['hemD'],
#   ['yjkA', 'yjkB'],
#   ['yjlA'],
#   ['yjlB'],
#   ['rex', 'ndh'],
#   ['uxaC'],
#   ['exuM'],
#   ['yjmC', 'yjmD', 'uxuA', 'yjmF', 'exuT'],
#   ['exuR'],
#   ['uxaB', 'uxaA'],
#   ['yjnA'],
#   ['yjoA'],
#   ['yjoB'],
#   ['rapA', 'phrA'],
#   ['yjpA'],
#   ['xlyB'],
#   ['yjqA'],
#   ['yjqB'],
#   ['yjqC'],
#   ['xkdA'],
#   ['xre'],
#   ['yjzJ', 'xkdB', 'xkdC', 'ykzK'],
#   ['xkdD', 'xtrA'],
#   ['xpf'],
#   ['xtmA',
#    'xtmB',
#    'xkdE',
#    'xkdF',
#    'xkdG',
#    'ykzL',
#    'xkdH',
#    'xkdI',
#    'xkdJ',
#    'ykzM',
#    'xkdK',
#    'xkdM'],
#   ['xkdN', 'xkzB', 'xkdO', 'xkdP', 'xkdQ', 'xkdR'],
#   ['xkdS', 'xkdT', 'xkdU', 'xkzA', 'xkdV', 'xkdW', 'xkdX', 'xepA'],
#   ['xhlA', 'xhlB', 'xlyA'],
#   ['spoIISB', 'spoIISA'],
#   ['pit', 'ykaA'],
#   ['ykbA'],
#   ['mhqA'],
#   ['ykcB', 'ykcC'],
#   ['htrA'],
#   ['proG'],
#   ['dppA', 'dppB', 'dppC', 'dppD', 'dppE'],
#   ['ykfA', 'ykfB', 'ykfC', 'ykfD'],
#   ['ykgB'],
#   ['ykgA'],
#   ['ykhA'],
#   ['hmp'],
#   ['ykzH'],
#   ['ykjA'],
#   ['ykkA', 'ykkB'],
#   ['ykkC', 'ykkD'],
#   ['purU'],
#   ['proB', 'proA'],
#   ['ohrA'],
#   ['ohrR'],
#   ['ohrB', 'ykzN'],
#   ['guaD'],
#   ['metE'],
#   ['ispA'],
#   ['rsbRB'],
#   ['thiX', 'thiW', 'thiV', 'thiU'],
#   ['ykoG', 'ykoH', 'ykoI'],
#   ['ykoJ'],
#   ['ykzD'],
#   ['mgtE'],
#   ['tnrA'],
#   ['ykzB'],
#   ['ykoL'],
#   ['ykoM'],
#   ['ykoN'],
#   ['ykoP'],
#   ['ykoQ'],
#   ['ykoS', 'ykoT'],
#   ['ligD', 'ykoV', 'ykoW'],
#   ['ykoX'],
#   ['ykoY'],
#   ['sigI', 'rsgI'],
#   ['sspD'],
#   ['ykrK'],
#   ['ykrL'],
#   ['ktrD'],
#   ['ykzP', 'ykzE'],
#   ['ykrP'],
#   ['kinE', 'ogt'],
#   ['mtnA', 'mtnK'],
#   ['mtnU'],
#   ['ykrV'],
#   ['mtnW', 'mtnX', 'mtnB', 'mtnD'],
#   ['ykvA'],
#   ['spo0E'],
#   ['eag'],
#   ['kinD'],
#   ['mhqR'],
#   ['motB', 'motA'],
#   ['clpE'],
#   ['ykvI'],
#   ['queC', 'queD', 'queE', 'ykvM'],
#   ['ykvN'],
#   ['ykvO'],
#   ['ykvP', 'ykzQ'],
#   ['ykvQ', 'ykzR'],
#   ['ykvR'],
#   ['ykvS'],
#   ['ykzS'],
#   ['ykvT'],
#   ['ykvU'],
#   ['stoA'],
#   ['zosA'],
#   ['ykvY'],
#   ['ykvZ'],
#   ['glcT'],
#   ['ptsG'],
#   ['ptsH', 'ptsI'],
#   ['splA'],
#   ['splB'],
#   ['ykwB'],
#   ['mcpC'],
#   ['ykwC'],
#   ['ykwD'],
#   ['pbpH'],
#   ['kinA'],
#   ['patA'],
#   ['ykzT'],
#   ['cheV'],
#   ['ykyB'],
#   ['ykuC'],
#   ['ykuD'],
#   ['ykuE'],
#   ['ykuF'],
#   ['fadG'],
#   ['ykzU'],
#   ['ykuH'],
#   ['ykuI'],
#   ['ykuJ'],
#   ['ykuK'],
#   ['ykzF'],
#   ['ykuL'],
#   ['ccpC'],
#   ['ykuN', 'ykuO', 'ykuP'],
#   ['dapH'],
#   ['dapL'],
#   ['ykuS'],
#   ['ykuT'],
#   ['ykuU'],
#   ['ykuV'],
#   ['rok'],
#   ['yknT'],
#   ['mobA'],
#   ['moeB', 'moeA', 'mobB', 'moaE', 'moaD'],
#   ['yknU', 'yknV'],
#   ['yknW', 'yknX', 'yknY', 'yknZ'],
#   ['fruR', 'fruK', 'fruA'],
#   ['sipT'],
#   ['ykoA'],
#   ['ykpA'],
#   ['ykpB'],
#   ['ampS'],
#   ['ykpC'],
#   ['mreBH'],
#   ['abh'],
#   ['kinC', 'ykqA'],
#   ['ktrC'],
#   ['adeC'],
#   ['rnjA', 'ykzG'],
#   ['ykrA'],
#   ['def'],
#   ['ykzV'],
#   ...])

# %%
#function to predict the operons in GFF file using the same logic as that for the PTT file
def predict_operons_gff(filepath, threshold=50):
    # Read the GFF file into a dataframe
    df = pd.read_csv(filepath, sep='\t', comment='#', header=None, usecols=[0, 3, 4, 6], names=['contig', 'start', 'stop','strand'])
    df = df.sort_values(['contig','start'])
    operons_list = []
    operon = [df['contig'].iloc[0]]
    prev_stop = df['stop'].iloc[0]
    for i in range(1, len(df)):
        curr_start = df['start'].iloc[i]
        curr_stop = df['stop'].iloc[i]
        curr_gene = df['contig'].iloc[i]
        if df['strand'].iloc[i] == df['strand'].iloc[i-1] and curr_start - prev_stop < threshold:
            operon.append(curr_gene)
        else:
            operons_list.append(operon)
            operon = [curr_gene]
        prev_stop = curr_stop
    operons_list.append(operon)
    return len(operons_list),operons_list

# %%
predict_operons_gff('2088090036.gff')
# Out:
# (12108,
#  [['HCP21_1000'],
#   ['HCP21_10000', 'HCP21_10001', 'HCP21_10002'],
#   ['HCP21_10003', 'HCP21_10004', 'HCP21_10005'],
#   ['HCP21_10006', 'HCP21_10007', 'HCP21_10007', 'HCP21_10008'],
#   ['HCP21_10009',
#    'HCP21_1001',
#    'HCP21_10010',
#    'HCP21_10010',
#    'HCP21_10011',
#    'HCP21_10012'],
#   ['HCP21_10013', 'HCP21_10014', 'HCP21_10015', 'HCP21_10016', 'HCP21_10017'],
#   ['HCP21_10018', 'HCP21_10019'],
#   ['HCP21_1002'],
#   ['HCP21_10020'],
#   ['HCP21_10020', 'HCP21_10021', 'HCP21_10022'],
#   ['HCP21_10023', 'HCP21_10024', 'HCP21_10025'],
#   ['HCP21_10026', 'HCP21_10027'],
#   ['HCP21_10028'],
#   ['HCP21_10029'],
#   ['HCP21_1003', 'HCP21_10030'],
#   ['HCP21_10031'],
#   ['HCP21_10032'],
#   ['HCP21_10033'],
#   ['HCP21_10034'],
#   ['HCP21_10035'],
#   ['HCP21_10035'],
#   ['HCP21_10036'],
#   ['HCP21_10037'],
#   ['HCP21_10038', 'HCP21_10039', 'HCP21_1004', 'HCP21_10040'],
#   ['HCP21_10041', 'HCP21_10042'],
#   ['HCP21_10043', 'HCP21_10044', 'HCP21_10045', 'HCP21_10046'],
#   ['HCP21_10046', 'HCP21_10047'],
#   ['HCP21_10048'],
#   ['HCP21_10049'],
#   ['HCP21_1005'],
#   ['HCP21_10050',
#    'HCP21_10050',
#    'HCP21_10051',
#    'HCP21_10052',
#    'HCP21_10053',
#    'HCP21_10054',
#    'HCP21_10055'],
#   ['HCP21_10055', 'HCP21_10055', 'HCP21_10057', 'HCP21_10058'],
#   ['HCP21_10059', 'HCP21_10060', 'HCP21_10061', 'HCP21_10061'],
#   ['HCP21_10062'],
#   ['HCP21_10063', 'HCP21_10064'],
#   ['HCP21_10064'],
#   ['HCP21_10065'],
#   ['HCP21_10066', 'HCP21_10067', 'HCP21_10068'],
#   ['HCP21_10069'],
#   ['HCP21_1007'],
#   ['HCP21_10070'],
#   ['HCP21_10071'],
#   ['HCP21_10072',
#    'HCP21_10073',
#    'HCP21_10074',
#    'HCP21_10075',
#    'HCP21_10076',
#    'HCP21_10077',
#    'HCP21_10078',
#    'HCP21_10079',
#    'HCP21_10079',
#    'HCP21_1008',
#    'HCP21_10080'],
#   ['HCP21_10081'],
#   ['HCP21_10081'],
#   ['HCP21_10082'],
#   ['HCP21_10083'],
#   ['HCP21_10084', 'HCP21_10085', 'HCP21_10086'],
#   ['HCP21_10087', 'HCP21_10088', 'HCP21_10089', 'HCP21_1009'],
#   ['HCP21_10090', 'HCP21_10091', 'HCP21_10092'],
#   ['HCP21_10093', 'HCP21_10094'],
#   ['HCP21_10095'],
#   ['HCP21_10096'],
#   ['HCP21_10097'],
#   ['HCP21_10098'],
#   ['HCP21_10099', 'HCP21_10099'],
#   ['HCP21_100_'],
#   ['HCP21_1010', 'HCP21_10100'],
#   ['HCP21_10101'],
#   ['HCP21_10102', 'HCP21_10103'],
#   ['HCP21_10104'],
#   ['HCP21_10105'],
#   ['HCP21_10106', 'HCP21_10107', 'HCP21_10108'],
#   ['HCP21_10109', 'HCP21_1011'],
#   ['HCP21_1011', 'HCP21_1011'],
#   ['HCP21_10110', 'HCP21_10110'],
#   ['HCP21_10110', 'HCP21_10111'],
#   ['HCP21_10112', 'HCP21_10113', 'HCP21_10114', 'HCP21_10115'],
#   ['HCP21_10116', 'HCP21_10117'],
#   ['HCP21_10118', 'HCP21_10119'],
#   ['HCP21_10119', 'HCP21_1012', 'HCP21_10120'],
#   ['HCP21_10120', 'HCP21_10121', 'HCP21_10122', 'HCP21_10123'],
#   ['HCP21_10125'],
#   ['HCP21_10126', 'HCP21_10127'],
#   ['HCP21_10128', 'HCP21_10129', 'HCP21_1013', 'HCP21_10130', 'HCP21_10131'],
#   ['HCP21_10132', 'HCP21_10133'],
#   ['HCP21_10133', 'HCP21_10134', 'HCP21_10135'],
#   ['HCP21_10136'],
#   ['HCP21_10137', 'HCP21_10138', 'HCP21_10139'],
#   ['HCP21_1014', 'HCP21_10140'],
#   ['HCP21_10141', 'HCP21_10142', 'HCP21_10143'],
#   ['HCP21_10143', 'HCP21_10144', 'HCP21_10145'],
#   ['HCP21_10146'],
#   ['HCP21_10147'],
#   ['HCP21_10148'],
#   ['HCP21_10149', 'HCP21_1015'],
#   ['HCP21_10150'],
#   ['HCP21_10151'],
#   ['HCP21_10151', 'HCP21_10152'],
#   ['HCP21_10154'],
#   ['HCP21_10155'],
#   ['HCP21_10156', 'HCP21_10156', 'HCP21_10157'],
#   ['HCP21_10157'],
#   ['HCP21_10158', 'HCP21_10159', 'HCP21_10159', 'HCP21_10160', 'HCP21_10160'],
#   ['HCP21_10160'],
#   ['HCP21_10161'],
#   ['HCP21_10162'],
#   ['HCP21_10162'],
#   ['HCP21_10163'],
#   ['HCP21_10164'],
#   ['HCP21_10165'],
#   ['HCP21_10166'],
#   ['HCP21_10167'],
#   ['HCP21_10169', 'HCP21_1017'],
#   ['HCP21_10170', 'HCP21_10171', 'HCP21_10172'],
#   ['HCP21_10173'],
#   ['HCP21_10174', 'HCP21_10175', 'HCP21_10176'],
#   ['HCP21_10177'],
#   ['HCP21_10178',
#    'HCP21_10179',
#    'HCP21_10180',
#    'HCP21_10181',
#    'HCP21_10182',
#    'HCP21_10182',
#    'HCP21_10182'],
#   ['HCP21_10182', 'HCP21_10182'],
#   ['HCP21_10183'],
#   ['HCP21_10184', 'HCP21_10184'],
#   ['HCP21_10185'],
#   ['HCP21_10185', 'HCP21_10187', 'HCP21_10188'],
#   ['HCP21_10190'],
#   ['HCP21_10190', 'HCP21_10191', 'HCP21_10192'],
#   ['HCP21_10193', 'HCP21_10194', 'HCP21_10195', 'HCP21_10195'],
#   ['HCP21_10195', 'HCP21_10196'],
#   ['HCP21_10197'],
#   ['HCP21_10198', 'HCP21_10199', 'HCP21_101_', 'HCP21_101_', 'HCP21_101_'],
#   ['HCP21_101_', 'HCP21_101_', 'HCP21_1020'],
#   ['HCP21_10200'],
#   ['HCP21_10201', 'HCP21_10202'],
#   ['HCP21_10203'],
#   ['HCP21_10204'],
#   ['HCP21_10205'],
#   ['HCP21_10206', 'HCP21_10207', 'HCP21_10209'],
#   ['HCP21_1021', 'HCP21_10210', 'HCP21_10211', 'HCP21_10212'],
#   ['HCP21_10213', 'HCP21_10214'],
#   ['HCP21_10215'],
#   ['HCP21_10216', 'HCP21_10217'],
#   ['HCP21_10218'],
#   ['HCP21_1022'],
#   ['HCP21_10220', 'HCP21_10221'],
#   ['HCP21_10222', 'HCP21_10223'],
#   ['HCP21_10224', 'HCP21_10225'],
#   ['HCP21_10226'],
#   ['HCP21_10227'],
#   ['HCP21_10228'],
#   ['HCP21_10228', 'HCP21_10229', 'HCP21_1023', 'HCP21_1023'],
#   ['HCP21_10232'],
#   ['HCP21_10233'],
#   ['HCP21_10234', 'HCP21_10235'],
#   ['HCP21_10237', 'HCP21_10238', 'HCP21_10239'],
#   ['HCP21_1024'],
#   ['HCP21_10240', 'HCP21_10241'],
#   ['HCP21_10242', 'HCP21_10243'],
#   ['HCP21_10244', 'HCP21_10245', 'HCP21_10246'],
#   ['HCP21_10247', 'HCP21_10248', 'HCP21_10249'],
#   ['HCP21_1025'],
#   ['HCP21_10250'],
#   ['HCP21_10250', 'HCP21_10252', 'HCP21_10253'],
#   ['HCP21_10253', 'HCP21_10254'],
#   ['HCP21_10255', 'HCP21_10255'],
#   ['HCP21_10256'],
#   ['HCP21_10257'],
#   ['HCP21_10258'],
#   ['HCP21_10258', 'HCP21_10259', 'HCP21_1026'],
#   ['HCP21_10260', 'HCP21_10261', 'HCP21_10262'],
#   ['HCP21_10262', 'HCP21_10263'],
#   ['HCP21_10264', 'HCP21_10265', 'HCP21_10266'],
#   ['HCP21_10267', 'HCP21_10268'],
#   ['HCP21_10269'],
#   ['HCP21_1027'],
#   ['HCP21_10270'],
#   ['HCP21_10271'],
#   ['HCP21_10272',
#    'HCP21_10273',
#    'HCP21_10274',
#    'HCP21_10275',
#    'HCP21_10276',
#    'HCP21_10277',
#    'HCP21_10278'],
#   ['HCP21_10279'],
#   ['HCP21_1028', 'HCP21_10280'],
#   ['HCP21_10281'],
#   ['HCP21_10282'],
#   ['HCP21_10283'],
#   ['HCP21_10284', 'HCP21_10285', 'HCP21_10286', 'HCP21_10287', 'HCP21_10288'],
#   ['HCP21_10289', 'HCP21_1029', 'HCP21_10290'],
#   ['HCP21_10290', 'HCP21_10291'],
#   ['HCP21_10292'],
#   ['HCP21_10293', 'HCP21_10294'],
#   ['HCP21_10295'],
#   ['HCP21_10296'],
#   ['HCP21_10297'],
#   ['HCP21_10298'],
#   ['HCP21_10299', 'HCP21_10299', 'HCP21_10299', 'HCP21_102_'],
#   ['HCP21_102_'],
#   ['HCP21_102_', 'HCP21_1030'],
#   ['HCP21_10300'],
#   ['HCP21_10301', 'HCP21_10302'],
#   ['HCP21_10303',
#    'HCP21_10304',
#    'HCP21_10305',
#    'HCP21_10306',
#    'HCP21_10307',
#    'HCP21_10308',
#    'HCP21_10308',
#    'HCP21_10309',
#    'HCP21_1031',
#    'HCP21_10310'],
#   ['HCP21_10311'],
#   ['HCP21_10312'],
#   ['HCP21_10313'],
#   ['HCP21_10314'],
#   ['HCP21_10315'],
#   ['HCP21_10316', 'HCP21_10317', 'HCP21_10318', 'HCP21_1032', 'HCP21_10320'],
#   ['HCP21_10320', 'HCP21_10321', 'HCP21_10322'],
#   ['HCP21_10323'],
#   ['HCP21_10324'],
#   ['HCP21_10325', 'HCP21_10326', 'HCP21_10327'],
#   ['HCP21_10327', 'HCP21_10328', 'HCP21_10329', 'HCP21_1033'],
#   ['HCP21_10330'],
#   ['HCP21_10331', 'HCP21_10332'],
#   ['HCP21_10333', 'HCP21_10334'],
#   ['HCP21_10334'],
#   ['HCP21_10334', 'HCP21_10335'],
#   ['HCP21_10336', 'HCP21_10337'],
#   ['HCP21_10338'],
#   ['HCP21_10338'],
#   ['HCP21_10339', 'HCP21_1034', 'HCP21_10340', 'HCP21_10340'],
#   ['HCP21_10341'],
#   ['HCP21_10343'],
#   ['HCP21_10344'],
#   ['HCP21_10345', 'HCP21_10345'],
#   ['HCP21_10346'],
#   ['HCP21_10347', 'HCP21_10348', 'HCP21_10349'],
#   ['HCP21_1035', 'HCP21_10350', 'HCP21_10351'],
#   ['HCP21_10352'],
#   ['HCP21_10353', 'HCP21_10354'],
#   ['HCP21_10355'],
#   ['HCP21_10356'],
#   ['HCP21_10357'],
#   ['HCP21_10358', 'HCP21_10359'],
#   ['HCP21_1036', 'HCP21_10360'],
#   ['HCP21_10361'],
#   ['HCP21_10361', 'HCP21_10362', 'HCP21_10363', 'HCP21_10364'],
#   ['HCP21_10365', 'HCP21_10366', 'HCP21_10367', 'HCP21_10368'],
#   ['HCP21_10369', 'HCP21_1037'],
#   ['HCP21_10370', 'HCP21_10371'],
#   ['HCP21_10372'],
#   ['HCP21_10373'],
#   ['HCP21_10374'],
#   ['HCP21_10374', 'HCP21_10375'],
#   ['HCP21_10376'],
#   ['HCP21_10376'],
#   ['HCP21_10376', 'HCP21_10377', 'HCP21_10378', 'HCP21_10379'],
#   ['HCP21_10379'],
#   ['HCP21_1038',
#    'HCP21_10380',
#    'HCP21_10381',
#    'HCP21_10382',
#    'HCP21_10383',
#    'HCP21_10384',
#    'HCP21_10385'],
#   ['HCP21_10386', 'HCP21_10387', 'HCP21_10388'],
#   ['HCP21_10389'],
#   ['HCP21_1039'],
#   ['HCP21_10390',
#    'HCP21_10391',
#    'HCP21_10392',
#    'HCP21_10392',
#    'HCP21_10393',
#    'HCP21_10394',
#    'HCP21_10395'],
#   ['HCP21_10395'],
#   ['HCP21_10396'],
#   ['HCP21_10397'],
#   ['HCP21_10398'],
#   ['HCP21_10399', 'HCP21_103_'],
#   ['HCP21_1040', 'HCP21_10400', 'HCP21_10400'],
#   ['HCP21_10401'],
#   ['HCP21_10401'],
#   ['HCP21_10401', 'HCP21_10402', 'HCP21_10402'],
#   ['HCP21_10403'],
#   ['HCP21_10404'],
#   ['HCP21_10404', 'HCP21_10405'],
#   ['HCP21_10406', 'HCP21_10407'],
#   ['HCP21_10408',
#    'HCP21_10409',
#    'HCP21_1041',
#    'HCP21_10410',
#    'HCP21_10411',
#    'HCP21_10411'],
#   ['HCP21_10412'],
#   ['HCP21_10414', 'HCP21_10415'],
#   ['HCP21_10416'],
#   ['HCP21_10417', 'HCP21_10417'],
#   ['HCP21_10417', 'HCP21_10418', 'HCP21_10418'],
#   ['HCP21_10419'],
#   ['HCP21_1042'],
#   ['HCP21_10420'],
#   ['HCP21_10421'],
#   ['HCP21_10422', 'HCP21_10423'],
#   ['HCP21_10424'],
#   ['HCP21_10425'],
#   ['HCP21_10425'],
#   ['HCP21_10426'],
#   ['HCP21_10427', 'HCP21_10428', 'HCP21_10429'],
#   ['HCP21_1043'],
#   ['HCP21_10430'],
#   ['HCP21_10431'],
#   ['HCP21_10432'],
#   ['HCP21_10433'],
#   ['HCP21_10434'],
#   ['HCP21_10435',
#    'HCP21_10436',
#    'HCP21_10437',
#    'HCP21_10437',
#    'HCP21_10438',
#    'HCP21_10439',
#    'HCP21_1044',
#    'HCP21_10440'],
#   ['HCP21_10441', 'HCP21_10442'],
#   ['HCP21_10443'],
#   ['HCP21_10444'],
#   ['HCP21_10445', 'HCP21_10446'],
#   ['HCP21_10446'],
#   ['HCP21_10447', 'HCP21_10448', 'HCP21_10449'],
#   ['HCP21_1045', 'HCP21_10450', 'HCP21_10450'],
#   ['HCP21_10451', 'HCP21_10452', 'HCP21_10453', 'HCP21_10455'],
#   ['HCP21_10455'],
#   ['HCP21_10456', 'HCP21_10457'],
#   ['HCP21_10458'],
#   ['HCP21_10458', 'HCP21_10459'],
#   ['HCP21_1046', 'HCP21_1046'],
#   ['HCP21_10460'],
#   ['HCP21_10460'],
#   ['HCP21_10461', 'HCP21_10462', 'HCP21_10463'],
#   ['HCP21_10464', 'HCP21_10465', 'HCP21_10465', 'HCP21_10466', 'HCP21_10467'],
#   ['HCP21_10469'],
#   ['HCP21_1047'],
#   ['HCP21_10470', 'HCP21_10472', 'HCP21_10473', 'HCP21_10475', 'HCP21_10476'],
#   ['HCP21_10477', 'HCP21_10478'],
#   ['HCP21_10479'],
#   ['HCP21_1048', 'HCP21_10480'],
#   ['HCP21_10481', 'HCP21_10482'],
#   ['HCP21_10482'],
#   ['HCP21_10483', 'HCP21_10484', 'HCP21_10485', 'HCP21_10486'],
#   ['HCP21_10488', 'HCP21_10489'],
#   ['HCP21_1049', 'HCP21_10490', 'HCP21_10491', 'HCP21_10492', 'HCP21_10493'],
#   ['HCP21_10493', 'HCP21_10494', 'HCP21_10495', 'HCP21_10497'],
#   ['HCP21_10498', 'HCP21_10499'],
#   ['HCP21_104_'],
#   ['HCP21_1050'],
#   ['HCP21_10500', 'HCP21_10501'],
#   ['HCP21_10502', 'HCP21_10503'],
#   ['HCP21_10504'],
#   ['HCP21_10505', 'HCP21_10505'],
#   ['HCP21_10506'],
#   ['HCP21_10507', 'HCP21_10508'],
#   ['HCP21_10509', 'HCP21_1051'],
#   ['HCP21_10510', 'HCP21_10511'],
#   ['HCP21_10512'],
#   ['HCP21_10512', 'HCP21_10512'],
#   ['HCP21_10512', 'HCP21_10513', 'HCP21_10514'],
#   ['HCP21_10515', 'HCP21_10516', 'HCP21_10517'],
#   ['HCP21_10518', 'HCP21_10519', 'HCP21_1052'],
#   ['HCP21_10520'],
#   ['HCP21_10521'],
#   ['HCP21_10522', 'HCP21_10522', 'HCP21_10523', 'HCP21_10524'],
#   ['HCP21_10525', 'HCP21_10526', 'HCP21_10527'],
#   ['HCP21_10528'],
#   ['HCP21_10529'],
#   ['HCP21_10529', 'HCP21_1053'],
#   ['HCP21_10530'],
#   ['HCP21_10531', 'HCP21_10532'],
#   ['HCP21_10533'],
#   ['HCP21_10534'],
#   ['HCP21_10535'],
#   ['HCP21_10536'],
#   ['HCP21_10537'],
#   ['HCP21_10538', 'HCP21_10539', 'HCP21_1054'],
#   ['HCP21_10540'],
#   ['HCP21_10541',
#    'HCP21_10543',
#    'HCP21_10543',
#    'HCP21_10544',
#    'HCP21_10545',
#    'HCP21_10546',
#    'HCP21_10547'],
#   ['HCP21_10548'],
#   ['HCP21_10549'],
#   ['HCP21_1055', 'HCP21_10550'],
#   ['HCP21_10550', 'HCP21_10551'],
#   ['HCP21_10551', 'HCP21_10552'],
#   ['HCP21_10552',
#    'HCP21_10553',
#    'HCP21_10555',
#    'HCP21_10556',
#    'HCP21_10556',
#    'HCP21_10557',
#    'HCP21_10558',
#    'HCP21_10559'],
#   ['HCP21_1056', 'HCP21_10560', 'HCP21_10561'],
#   ['HCP21_10562'],
#   ['HCP21_10563'],
#   ['HCP21_10563'],
#   ['HCP21_10564'],
#   ['HCP21_10564'],
#   ['HCP21_10565',
#    'HCP21_10566',
#    'HCP21_10566',
#    'HCP21_10567',
#    'HCP21_10568',
#    'HCP21_10569'],
#   ['HCP21_1057', 'HCP21_10570'],
#   ['HCP21_10571'],
#   ['HCP21_10572', 'HCP21_10573'],
#   ['HCP21_10574', 'HCP21_10575'],
#   ['HCP21_10576'],
#   ['HCP21_10577', 'HCP21_10578'],
#   ['HCP21_10579', 'HCP21_1058'],
#   ['HCP21_10580', 'HCP21_10581', 'HCP21_10582'],
#   ['HCP21_10583'],
#   ['HCP21_10584', 'HCP21_10585'],
#   ['HCP21_10586'],
#   ['HCP21_10586', 'HCP21_10587', 'HCP21_10587', 'HCP21_10588', 'HCP21_10589'],
#   ['HCP21_1059'],
#   ['HCP21_10590'],
#   ['HCP21_10591'],
#   ['HCP21_10592'],
#   ['HCP21_10592'],
#   ['HCP21_10593'],
#   ['HCP21_10593'],
#   ['HCP21_10593'],
#   ['HCP21_10594'],
#   ['HCP21_10595', 'HCP21_10596'],
#   ['HCP21_10597'],
#   ['HCP21_10598', 'HCP21_10599'],
#   ['HCP21_10599'],
#   ['HCP21_10599', 'HCP21_105_'],
#   ['HCP21_10600'],
#   ['HCP21_10601', 'HCP21_10602'],
#   ['HCP21_10603', 'HCP21_10603'],
#   ['HCP21_10604'],
#   ['HCP21_10605', 'HCP21_10606'],
#   ['HCP21_10607'],
#   ['HCP21_10608'],
#   ['HCP21_10609', 'HCP21_1061', 'HCP21_1061'],
#   ['HCP21_10610', 'HCP21_10611'],
#   ['HCP21_10612',
#    'HCP21_10613',
#    'HCP21_10614',
#    'HCP21_10615',
#    'HCP21_10616',
#    'HCP21_10616',
#    'HCP21_10616',
#    'HCP21_10617'],
#   ['HCP21_10618'],
#   ['HCP21_10619', 'HCP21_1062'],
#   ['HCP21_10620'],
#   ['HCP21_10620', 'HCP21_10621', 'HCP21_10622'],
#   ['HCP21_10623'],
#   ['HCP21_10624', 'HCP21_10625', 'HCP21_10626', 'HCP21_10627'],
#   ['HCP21_10627'],
#   ['HCP21_10628', 'HCP21_10629', 'HCP21_10629'],
#   ['HCP21_1063', 'HCP21_10630', 'HCP21_10631', 'HCP21_10632'],
#   ['HCP21_10633', 'HCP21_10634', 'HCP21_10635'],
#   ['HCP21_10636'],
#   ['HCP21_10637'],
#   ['HCP21_10638'],
#   ['HCP21_10638', 'HCP21_10639'],
#   ['HCP21_1064'],
#   ['HCP21_1064', 'HCP21_10640', 'HCP21_10641'],
#   ['HCP21_10642'],
#   ['HCP21_10643'],
#   ['HCP21_10644', 'HCP21_10645'],
#   ['HCP21_10646'],
#   ['HCP21_10647', 'HCP21_10647', 'HCP21_10648'],
#   ['HCP21_10649', 'HCP21_10649'],
#   ['HCP21_1065', 'HCP21_10650', 'HCP21_10651'],
#   ['HCP21_10652'],
#   ['HCP21_10653', 'HCP21_10653', 'HCP21_10654'],
#   ['HCP21_10654'],
#   ['HCP21_10655'],
#   ['HCP21_10656'],
#   ['HCP21_10657'],
#   ['HCP21_10658',
#    'HCP21_10659',
#    'HCP21_1066',
#    'HCP21_10660',
#    'HCP21_10661',
#    'HCP21_10662',
#    'HCP21_10663'],
#   ['HCP21_10663', 'HCP21_10664', 'HCP21_10665', 'HCP21_10666'],
#   ['HCP21_10667', 'HCP21_10668'],
#   ['HCP21_10669', 'HCP21_1067', 'HCP21_10670', 'HCP21_10671', 'HCP21_10672'],
#   ['HCP21_10675'],
#   ['HCP21_10676'],
#   ['HCP21_10677', 'HCP21_10678'],
#   ['HCP21_10679', 'HCP21_1068'],
#   ['HCP21_10680', 'HCP21_10681', 'HCP21_10682'],
#   ['HCP21_10683', 'HCP21_10684', 'HCP21_10685'],
#   ['HCP21_10685', 'HCP21_10686'],
#   ['HCP21_10687', 'HCP21_10688', 'HCP21_10689'],
#   ['HCP21_1069'],
#   ['HCP21_10690'],
#   ['HCP21_10691'],
#   ['HCP21_10691', 'HCP21_10693'],
#   ['HCP21_10694'],
#   ['HCP21_10695'],
#   ['HCP21_10697', 'HCP21_10698'],
#   ['HCP21_10699', 'HCP21_106_'],
#   ['HCP21_106_'],
#   ['HCP21_106_', 'HCP21_1070', 'HCP21_10700', 'HCP21_10701', 'HCP21_10701'],
#   ['HCP21_10702'],
#   ['HCP21_10703'],
#   ['HCP21_10704'],
#   ['HCP21_10705'],
#   ['HCP21_10705', 'HCP21_10706', 'HCP21_10707'],
#   ['HCP21_10708', 'HCP21_10709'],
#   ['HCP21_10709'],
#   ['HCP21_10709', 'HCP21_1071', 'HCP21_10710'],
#   ['HCP21_10711', 'HCP21_10712'],
#   ['HCP21_10712', 'HCP21_10712'],
#   ['HCP21_10713',
#    'HCP21_10714',
#    'HCP21_10715',
#    'HCP21_10716',
#    'HCP21_10717',
#    'HCP21_10718'],
#   ['HCP21_10719', 'HCP21_1072'],
#   ['HCP21_10720', 'HCP21_10721'],
#   ['HCP21_10722'],
#   ['HCP21_10723', 'HCP21_10724', 'HCP21_10725', 'HCP21_10726'],
#   ['HCP21_10727',
#    'HCP21_10728',
#    'HCP21_10729',
#    'HCP21_1073',
#    'HCP21_10730',
#    'HCP21_10731'],
#   ['HCP21_10731'],
#   ['HCP21_10732'],
#   ['HCP21_10733', 'HCP21_10734', 'HCP21_10735'],
#   ['HCP21_10736'],
#   ['HCP21_10736', 'HCP21_10737', 'HCP21_10738', 'HCP21_10739'],
#   ['HCP21_1074'],
#   ['HCP21_10740', 'HCP21_10741', 'HCP21_10742', 'HCP21_10743', 'HCP21_10744'],
#   ['HCP21_10745'],
#   ['HCP21_10745'],
#   ['HCP21_10746'],
#   ['HCP21_10747', 'HCP21_10748', 'HCP21_10749'],
#   ['HCP21_1075', 'HCP21_10750'],
#   ['HCP21_10751',
#    'HCP21_10753',
#    'HCP21_10754',
#    'HCP21_10755',
#    'HCP21_10756',
#    'HCP21_10757',
#    'HCP21_10758',
#    'HCP21_10759'],
#   ['HCP21_10760', 'HCP21_10760'],
#   ['HCP21_10761'],
#   ['HCP21_10762', 'HCP21_10763', 'HCP21_10764', 'HCP21_10765'],
#   ['HCP21_10766',
#    'HCP21_10767',
#    'HCP21_10768',
#    'HCP21_1077',
#    'HCP21_10770',
#    'HCP21_10771'],
#   ['HCP21_10771'],
#   ['HCP21_10772'],
#   ['HCP21_10773'],
#   ['HCP21_10774', 'HCP21_10775'],
#   ['HCP21_10776'],
#   ['HCP21_10777',
#    'HCP21_10778',
#    'HCP21_10780',
#    'HCP21_10781',
#    'HCP21_10782',
#    'HCP21_10784'],
#   ['HCP21_10784', 'HCP21_10786'],
#   ['HCP21_10787', 'HCP21_10788'],
#   ['HCP21_10789', 'HCP21_1079', 'HCP21_10790', 'HCP21_10791', 'HCP21_10792'],
#   ['HCP21_10793', 'HCP21_10794', 'HCP21_10795', 'HCP21_10796', 'HCP21_10797'],
#   ['HCP21_10798'],
#   ['HCP21_10799'],
#   ['HCP21_107_', 'HCP21_10800'],
#   ['HCP21_10801'],
#   ['HCP21_10802'],
#   ['HCP21_10803', 'HCP21_10803', 'HCP21_10804'],
#   ['HCP21_10805'],
#   ['HCP21_10806'],
#   ['HCP21_10807'],
#   ['HCP21_10807', 'HCP21_10808', 'HCP21_10809'],
#   ['HCP21_1081'],
#   ['HCP21_1081', 'HCP21_10810'],
#   ['HCP21_10811', 'HCP21_10812', 'HCP21_10813', 'HCP21_10814'],
#   ['HCP21_10815'],
#   ['HCP21_10816'],
#   ['HCP21_10817'],
#   ['HCP21_10818', 'HCP21_1082'],
#   ['HCP21_10820', 'HCP21_10821'],
#   ['HCP21_10822', 'HCP21_10823'],
#   ['HCP21_10824', 'HCP21_10825', 'HCP21_10826', 'HCP21_10827'],
#   ['HCP21_10828', 'HCP21_10829'],
#   ['HCP21_1083'],
#   ['HCP21_10830'],
#   ['HCP21_10831'],
#   ['HCP21_10832', 'HCP21_10833', 'HCP21_10834', 'HCP21_10836'],
#   ['HCP21_10836', 'HCP21_10837'],
#   ['HCP21_10838'],
#   ['HCP21_10838', 'HCP21_1084', 'HCP21_10840'],
#   ['HCP21_10841', 'HCP21_10841'],
#   ['HCP21_10842', 'HCP21_10843'],
#   ['HCP21_10843', 'HCP21_10844'],
#   ['HCP21_10845', 'HCP21_10846', 'HCP21_10847', 'HCP21_10848'],
#   ['HCP21_10849', 'HCP21_1085'],
#   ['HCP21_10850', 'HCP21_10851'],
#   ['HCP21_10851'],
#   ['HCP21_10851'],
#   ['HCP21_10852', 'HCP21_10853'],
#   ['HCP21_10854'],
#   ['HCP21_10855', 'HCP21_10856'],
#   ['HCP21_10857'],
#   ['HCP21_10858', 'HCP21_10859'],
#   ['HCP21_1086'],
#   ['HCP21_10860'],
#   ['HCP21_10861'],
#   ['HCP21_10862'],
#   ['HCP21_10863'],
#   ['HCP21_10864'],
#   ['HCP21_10865', 'HCP21_10867'],
#   ['HCP21_10868', 'HCP21_10869', 'HCP21_1087', 'HCP21_10870'],
#   ['HCP21_10871', 'HCP21_10872', 'HCP21_10873'],
#   ['HCP21_10874'],
#   ['HCP21_10875', 'HCP21_10876', 'HCP21_10877'],
#   ['HCP21_10878'],
#   ['HCP21_10879', 'HCP21_1088'],
#   ['HCP21_10880'],
#   ['HCP21_10881', 'HCP21_10882', 'HCP21_10883', 'HCP21_10884', 'HCP21_10885'],
#   ['HCP21_10887'],
#   ['HCP21_10888'],
#   ['HCP21_10889'],
#   ['HCP21_1089'],
#   ['HCP21_10890'],
#   ['HCP21_10891'],
#   ['HCP21_10892'],
#   ['HCP21_10893'],
#   ['HCP21_10894'],
#   ['HCP21_10895', 'HCP21_10897'],
#   ['HCP21_10898', 'HCP21_10899'],
#   ['HCP21_108_'],
#   ['HCP21_108_', 'HCP21_1090'],
#   ['HCP21_10900', 'HCP21_10901'],
#   ['HCP21_10902'],
#   ['HCP21_10903', 'HCP21_10904', 'HCP21_10904'],
#   ['HCP21_10905'],
#   ['HCP21_10905'],
#   ['HCP21_10906'],
#   ['HCP21_10907'],
#   ['HCP21_10908'],
#   ['HCP21_10909'],
#   ['HCP21_1091'],
#   ['HCP21_1091'],
#   ['HCP21_10910', 'HCP21_10912'],
#   ['HCP21_10912'],
#   ['HCP21_10913'],
#   ['HCP21_10914', 'HCP21_10915', 'HCP21_10915'],
#   ['HCP21_10916'],
#   ['HCP21_10917'],
#   ['HCP21_10918',
#    'HCP21_10919',
#    'HCP21_10919',
#    'HCP21_1092',
#    'HCP21_1092',
#    'HCP21_10920'],
#   ['HCP21_10921', 'HCP21_10922'],
#   ['HCP21_10923'],
#   ['HCP21_10923', 'HCP21_10924'],
#   ['HCP21_10924', 'HCP21_10924', 'HCP21_10925'],
#   ['HCP21_10926'],
#   ['HCP21_10927', 'HCP21_10928'],
#   ['HCP21_10929'],
#   ['HCP21_1093', 'HCP21_10930', 'HCP21_10932'],
#   ['HCP21_10933', 'HCP21_10934'],
#   ['HCP21_10935'],
#   ['HCP21_10937', 'HCP21_10938', 'HCP21_10939', 'HCP21_1094'],
#   ['HCP21_10941'],
#   ['HCP21_10942', 'HCP21_10943', 'HCP21_10944'],
#   ['HCP21_10944', 'HCP21_10945', 'HCP21_10946'],
#   ['HCP21_10947', 'HCP21_10948'],
#   ['HCP21_10948'],
#   ['HCP21_10949'],
#   ['HCP21_1095', 'HCP21_10950', 'HCP21_10951', 'HCP21_1096', 'HCP21_1097'],
#   ['HCP21_1098', 'HCP21_1099'],
#   ['HCP21_109_'],
#   ['HCP21_109_', 'HCP21_109_', 'HCP21_109_', 'HCP21_10__'],
#   ['HCP21_10__', 'HCP21_10__', 'HCP21_10__'],
#   ['HCP21_1101', 'HCP21_1102', 'HCP21_1103', 'HCP21_1104'],
#   ['HCP21_1105'],
#   ['HCP21_1106', 'HCP21_1107', 'HCP21_1108'],
#   ['HCP21_1109', 'HCP21_110_', 'HCP21_1110', 'HCP21_1111'],
#   ['HCP21_1112'],
#   ['HCP21_1113'],
#   ['HCP21_1114'],
#   ['HCP21_1115', 'HCP21_1115', 'HCP21_1116'],
#   ['HCP21_1117',
#    'HCP21_1118',
#    'HCP21_1119',
#    'HCP21_111_',
#    'HCP21_111_',
#    'HCP21_111_',
#    'HCP21_1120'],
#   ['HCP21_1121'],
#   ['HCP21_1123', 'HCP21_1124'],
#   ['HCP21_1125', 'HCP21_1126'],
#   ['HCP21_1127', 'HCP21_1128'],
#   ['HCP21_1129'],
#   ['HCP21_112_', 'HCP21_1130'],
#   ['HCP21_1131', 'HCP21_1132', 'HCP21_1133', 'HCP21_1134'],
#   ['HCP21_1135'],
#   ['HCP21_1136'],
#   ['HCP21_1137'],
#   ['HCP21_1138'],
#   ['HCP21_1139'],
#   ['HCP21_1139', 'HCP21_113_'],
#   ['HCP21_113_'],
#   ['HCP21_113_', 'HCP21_1140'],
#   ['HCP21_1141'],
#   ['HCP21_1142'],
#   ['HCP21_1143'],
#   ['HCP21_1144', 'HCP21_1145', 'HCP21_1146'],
#   ['HCP21_1147', 'HCP21_1148', 'HCP21_1149'],
#   ['HCP21_1149'],
#   ['HCP21_114_'],
#   ['HCP21_1150',
#    'HCP21_1151',
#    'HCP21_1151',
#    'HCP21_1152',
#    'HCP21_1153',
#    'HCP21_1154'],
#   ['HCP21_1155', 'HCP21_1156'],
#   ['HCP21_1157'],
#   ['HCP21_1158', 'HCP21_1159', 'HCP21_115_'],
#   ['HCP21_1160',
#    'HCP21_1161',
#    'HCP21_1162',
#    'HCP21_1164',
#    'HCP21_1165',
#    'HCP21_1166'],
#   ['HCP21_1167', 'HCP21_1168'],
#   ['HCP21_1169'],
#   ['HCP21_116_'],
#   ['HCP21_116_', 'HCP21_116_', 'HCP21_116_', 'HCP21_116_'],
#   ['HCP21_116_',
#    'HCP21_116_',
#    'HCP21_116_',
#    'HCP21_116_',
#    'HCP21_116_',
#    'HCP21_1170'],
#   ['HCP21_1171', 'HCP21_1172', 'HCP21_1173'],
#   ['HCP21_1174', 'HCP21_1175', 'HCP21_1176', 'HCP21_1177', 'HCP21_1178'],
#   ['HCP21_1179', 'HCP21_117_'],
#   ['HCP21_1180', 'HCP21_1181', 'HCP21_1182'],
#   ['HCP21_1183', 'HCP21_1184'],
#   ['HCP21_1185'],
#   ['HCP21_1186', 'HCP21_1187'],
#   ['HCP21_1188'],
#   ['HCP21_1189', 'HCP21_1189'],
#   ['HCP21_118_', 'HCP21_118_', 'HCP21_118_'],
#   ['HCP21_1191'],
#   ['HCP21_1192', 'HCP21_1193', 'HCP21_1194'],
#   ['HCP21_1195', 'HCP21_1196', 'HCP21_1197', 'HCP21_1198'],
#   ['HCP21_1199'],
#   ['HCP21_119_', 'HCP21_119_'],
#   ['HCP21_119_', 'HCP21_11__', 'HCP21_1200'],
#   ['HCP21_1201'],
#   ['HCP21_1201', 'HCP21_1203', 'HCP21_1203'],
#   ['HCP21_1204', 'HCP21_1204'],
#   ['HCP21_1205'],
#   ['HCP21_1205'],
#   ['HCP21_1206'],
#   ['HCP21_1207'],
#   ['HCP21_1208'],
#   ['HCP21_1209', 'HCP21_120_'],
#   ['HCP21_120_'],
#   ['HCP21_1210', 'HCP21_1211'],
#   ['HCP21_1212'],
#   ['HCP21_1213'],
#   ['HCP21_1214', 'HCP21_1215', 'HCP21_1216'],
#   ['HCP21_1217', 'HCP21_1218'],
#   ['HCP21_1219', 'HCP21_121_'],
#   ['HCP21_121_'],
#   ['HCP21_121_'],
#   ['HCP21_121_'],
#   ['HCP21_121_'],
#   ['HCP21_1221'],
#   ['HCP21_1223'],
#   ['HCP21_1224'],
#   ['HCP21_1225'],
#   ['HCP21_1226'],
#   ['HCP21_1227'],
#   ['HCP21_1228'],
#   ['HCP21_1229'],
#   ['HCP21_1229'],
#   ['HCP21_122_', 'HCP21_1230'],
#   ['HCP21_1231', 'HCP21_1232'],
#   ['HCP21_1233', 'HCP21_1234'],
#   ['HCP21_1234'],
#   ['HCP21_1236', 'HCP21_1237', 'HCP21_1238'],
#   ['HCP21_1239', 'HCP21_123_'],
#   ['HCP21_123_', 'HCP21_123_'],
#   ['HCP21_123_'],
#   ['HCP21_1241'],
#   ['HCP21_1242'],
#   ['HCP21_1243'],
#   ['HCP21_1244', 'HCP21_1245'],
#   ['HCP21_1246', 'HCP21_1248', 'HCP21_1249', 'HCP21_124_'],
#   ['HCP21_124_'],
#   ['HCP21_124_'],
#   ['HCP21_1250'],
#   ['HCP21_1251'],
#   ['HCP21_1252'],
#   ['HCP21_1252'],
#   ['HCP21_1253', 'HCP21_1254', 'HCP21_1255'],
#   ['HCP21_1256', 'HCP21_1257', 'HCP21_1258', 'HCP21_1259'],
#   ['HCP21_125_'],
#   ['HCP21_125_'],
#   ['HCP21_1260',
#    'HCP21_1261',
#    'HCP21_1262',
#    'HCP21_1264',
#    'HCP21_1265',
#    'HCP21_1266'],
#   ['HCP21_1267'],
#   ['HCP21_1268'],
#   ['HCP21_1268'],
#   ['HCP21_1269', 'HCP21_126_', 'HCP21_126_', 'HCP21_126_'],
#   ['HCP21_126_',
#    'HCP21_1270',
#    'HCP21_1271',
#    'HCP21_1272',
#    'HCP21_1273',
#    'HCP21_1274',
#    'HCP21_1275'],
#   ['HCP21_1276'],
#   ['HCP21_1276',
#    'HCP21_1277',
#    'HCP21_1278',
#    'HCP21_1279',
#    'HCP21_127_',
#    'HCP21_127_'],
#   ['HCP21_127_', 'HCP21_127_'],
#   ['HCP21_1280'],
#   ['HCP21_1281', 'HCP21_1282', 'HCP21_1283', 'HCP21_1285', 'HCP21_1286'],
#   ['HCP21_1287'],
#   ['HCP21_1288'],
#   ['HCP21_1289'],
#   ['HCP21_1289', 'HCP21_128_', 'HCP21_128_', 'HCP21_128_'],
#   ['HCP21_1290', 'HCP21_1291', 'HCP21_1292'],
#   ['HCP21_1293'],
#   ['HCP21_1294'],
#   ['HCP21_1295'],
#   ['HCP21_1297', 'HCP21_1298'],
#   ['HCP21_1299'],
#   ['HCP21_129_'],
#   ['HCP21_129_', 'HCP21_129_'],
#   ['HCP21_12__', 'HCP21_1300', 'HCP21_1301'],
#   ['HCP21_1302'],
#   ['HCP21_1303', 'HCP21_1304'],
#   ['HCP21_1305', 'HCP21_1306'],
#   ['HCP21_1307', 'HCP21_1308'],
#   ['HCP21_130_'],
#   ['HCP21_1310'],
#   ['HCP21_1312'],
#   ['HCP21_1313'],
#   ['HCP21_1314'],
#   ['HCP21_1315', 'HCP21_1315', 'HCP21_1316'],
#   ['HCP21_1317', 'HCP21_1317', 'HCP21_1318'],
#   ['HCP21_1319', 'HCP21_131_'],
#   ['HCP21_1320'],
#   ['HCP21_1321'],
#   ['HCP21_1321'],
#   ['HCP21_1322', 'HCP21_1323'],
#   ['HCP21_1323', 'HCP21_1324'],
#   ['HCP21_1325', 'HCP21_1326'],
#   ['HCP21_1327', 'HCP21_1328', 'HCP21_1329', 'HCP21_1329'],
#   ['HCP21_132_'],
#   ['HCP21_132_'],
#   ['HCP21_1330'],
#   ['HCP21_1331'],
#   ['HCP21_1331', 'HCP21_1332', 'HCP21_1333'],
#   ['HCP21_1334'],
#   ['HCP21_1335', 'HCP21_1335'],
#   ['HCP21_1336'],
#   ['HCP21_1337', 'HCP21_1338'],
#   ['HCP21_1339', 'HCP21_133_'],
#   ['HCP21_133_'],
#   ['HCP21_133_',
#    'HCP21_133_',
#    'HCP21_1340',
#    'HCP21_1342',
#    'HCP21_1343',
#    'HCP21_1344'],
#   ['HCP21_1345', 'HCP21_1346', 'HCP21_1347', 'HCP21_1348', 'HCP21_1349'],
#   ['HCP21_134_'],
#   ['HCP21_1350'],
#   ['HCP21_1350', 'HCP21_1351', 'HCP21_1352', 'HCP21_1353'],
#   ['HCP21_1354', 'HCP21_1355', 'HCP21_1356'],
#   ['HCP21_1356', 'HCP21_1357', 'HCP21_1358'],
#   ['HCP21_1359'],
#   ['HCP21_135_'],
#   ['HCP21_135_'],
#   ['HCP21_135_', 'HCP21_1360'],
#   ['HCP21_1361'],
#   ['HCP21_1362', 'HCP21_1363'],
#   ['HCP21_1364', 'HCP21_1365'],
#   ['HCP21_1365', 'HCP21_1365', 'HCP21_1366'],
#   ['HCP21_1367', 'HCP21_1368', 'HCP21_1369', 'HCP21_136_'],
#   ['HCP21_1370', 'HCP21_1371'],
#   ['HCP21_1372', 'HCP21_1373', 'HCP21_1373', 'HCP21_1374'],
#   ['HCP21_1376'],
#   ['HCP21_1377', 'HCP21_1378'],
#   ['HCP21_1379', 'HCP21_137_'],
#   ['HCP21_137_'],
#   ['HCP21_137_'],
#   ['HCP21_137_', 'HCP21_137_'],
#   ['HCP21_137_'],
#   ['HCP21_137_', 'HCP21_1380', 'HCP21_1381'],
#   ['HCP21_1382', 'HCP21_1382'],
#   ['HCP21_1384'],
#   ['HCP21_1385', 'HCP21_1386'],
#   ['HCP21_1387', 'HCP21_1388', 'HCP21_1389'],
#   ['HCP21_1389', 'HCP21_138_'],
#   ['HCP21_138_',
#    'HCP21_138_',
#    'HCP21_138_',
#    'HCP21_138_',
#    'HCP21_138_',
#    'HCP21_138_',
#    'HCP21_1390'],
#   ['HCP21_1391', 'HCP21_1392'],
#   ['HCP21_1393', 'HCP21_1394', 'HCP21_1395'],
#   ['HCP21_1396'],
#   ['HCP21_1397'],
#   ['HCP21_1399', 'HCP21_139_', 'HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_', 'HCP21_139_', 'HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_'],
#   ['HCP21_139_', 'HCP21_13__', 'HCP21_13__'],
#   ['HCP21_13__', 'HCP21_13__'],
#   ['HCP21_1400'],
#   ['HCP21_1401', 'HCP21_1402'],
#   ['HCP21_1404', 'HCP21_1405'],
#   ['HCP21_1406', 'HCP21_1407', 'HCP21_1408', 'HCP21_1409', 'HCP21_1409'],
#   ['HCP21_140_', 'HCP21_1410', 'HCP21_1410'],
#   ['HCP21_1411'],
#   ['HCP21_1412'],
#   ['HCP21_1413'],
#   ['HCP21_1414', 'HCP21_1415'],
#   ['HCP21_1416'],
#   ['HCP21_1418'],
#   ['HCP21_1419', 'HCP21_141_', 'HCP21_141_', 'HCP21_141_', 'HCP21_1420'],
#   ['HCP21_1420'],
#   ['HCP21_1421'],
#   ['HCP21_1422', 'HCP21_1423', 'HCP21_1424'],
#   ['HCP21_1425'],
#   ['HCP21_1427'],
#   ['HCP21_1428', 'HCP21_1429', 'HCP21_142_'],
#   ['HCP21_142_'],
#   ['HCP21_142_'],
#   ['HCP21_142_'],
#   ['HCP21_142_', 'HCP21_142_'],
#   ['HCP21_142_'],
#   ['HCP21_1430', 'HCP21_1431'],
#   ['HCP21_1431', 'HCP21_1432', 'HCP21_1432', 'HCP21_1433'],
#   ['HCP21_1434', 'HCP21_1435'],
#   ['HCP21_1436', 'HCP21_1437'],
#   ['HCP21_1438', 'HCP21_1439', 'HCP21_143_'],
#   ['HCP21_143_'],
#   ['HCP21_143_'],
#   ['HCP21_1440'],
#   ['HCP21_1441'],
#   ['HCP21_1442'],
#   ['HCP21_1443'],
#   ['HCP21_1443', 'HCP21_1444'],
#   ['HCP21_1445'],
#   ['HCP21_1446'],
#   ['HCP21_1447',
#    'HCP21_1448',
#    'HCP21_1449',
#    'HCP21_144_',
#    'HCP21_1450',
#    'HCP21_1451'],
#   ['HCP21_1452', 'HCP21_1453'],
#   ['HCP21_1455'],
#   ['HCP21_1456', 'HCP21_1457'],
#   ['HCP21_1458'],
#   ['HCP21_1459'],
#   ['HCP21_1459', 'HCP21_145_'],
#   ['HCP21_1460'],
#   ['HCP21_1461',
#    'HCP21_1462',
#    'HCP21_1463',
#    'HCP21_1464',
#    'HCP21_1465',
#    'HCP21_1466'],
#   ['HCP21_1466', 'HCP21_1467'],
#   ['HCP21_1468'],
#   ['HCP21_146_'],
#   ['HCP21_146_'],
#   ['HCP21_146_'],
#   ['HCP21_146_', 'HCP21_146_', 'HCP21_1470'],
#   ['HCP21_1471', 'HCP21_1472'],
#   ['HCP21_1473'],
#   ['HCP21_1473'],
#   ['HCP21_1474'],
#   ['HCP21_1475'],
#   ['HCP21_1476'],
#   ['HCP21_1477'],
#   ['HCP21_1478', 'HCP21_1479'],
#   ['HCP21_147_', 'HCP21_147_'],
#   ['HCP21_147_', 'HCP21_1480', 'HCP21_1481', 'HCP21_1482'],
#   ['HCP21_1484', 'HCP21_1485', 'HCP21_1486', 'HCP21_1487'],
#   ['HCP21_1488', 'HCP21_1489'],
#   ['HCP21_1489'],
#   ['HCP21_148_'],
#   ['HCP21_1490', 'HCP21_1491', 'HCP21_1492'],
#   ['HCP21_1493', 'HCP21_1494'],
#   ['HCP21_1495'],
#   ['HCP21_1496'],
#   ['HCP21_1497', 'HCP21_1498'],
#   ['HCP21_1499'],
#   ['HCP21_149_', 'HCP21_149_'],
#   ['HCP21_149_'],
#   ['HCP21_149_'],
#   ['HCP21_149_'],
#   ['HCP21_149_',
#    'HCP21_14__',
#    'HCP21_14__',
#    'HCP21_14__',
#    'HCP21_14__',
#    'HCP21_14__',
#    'HCP21_14__'],
#   ['HCP21_14__'],
#   ['HCP21_14__',
#    'HCP21_14__',
#    'HCP21_1500',
#    'HCP21_1501',
#    'HCP21_1502',
#    'HCP21_1503'],
#   ['HCP21_1504', 'HCP21_1505'],
#   ['HCP21_1506', 'HCP21_1507'],
#   ['HCP21_150_'],
#   ['HCP21_1510'],
#   ['HCP21_1511'],
#   ['HCP21_1512', 'HCP21_1513', 'HCP21_1513', 'HCP21_1514'],
#   ['HCP21_1515'],
#   ['HCP21_1516'],
#   ['HCP21_1518', 'HCP21_1519', 'HCP21_1519'],
#   ['HCP21_151_', 'HCP21_1520'],
#   ['HCP21_1520', 'HCP21_1521'],
#   ['HCP21_1522', 'HCP21_1523', 'HCP21_1524'],
#   ['HCP21_1525'],
#   ['HCP21_1526', 'HCP21_1527', 'HCP21_1528', 'HCP21_1529', 'HCP21_152_'],
#   ['HCP21_152_'],
#   ['HCP21_152_'],
#   ['HCP21_1530'],
#   ['HCP21_1531'],
#   ['HCP21_1532', 'HCP21_1533', 'HCP21_1534'],
#   ['HCP21_1535', 'HCP21_1536', 'HCP21_1537'],
#   ['HCP21_1538'],
#   ['HCP21_1538', 'HCP21_1539'],
#   ['HCP21_153_'],
#   ['HCP21_153_', 'HCP21_153_'],
#   ['HCP21_153_'],
#   ['HCP21_153_'],
#   ['HCP21_153_',
#    'HCP21_153_',
#    'HCP21_1540',
#    'HCP21_1541',
#    'HCP21_1541',
#    'HCP21_1542'],
#   ['HCP21_1543', 'HCP21_1544', 'HCP21_1545'],
#   ['HCP21_1546'],
#   ['HCP21_1547', 'HCP21_1548'],
#   ['HCP21_1549'],
#   ['HCP21_154_'],
#   ['HCP21_154_'],
#   ['HCP21_154_', 'HCP21_154_'],
#   ['HCP21_154_', 'HCP21_154_', 'HCP21_1550', 'HCP21_1551'],
#   ['HCP21_1552', 'HCP21_1553', 'HCP21_1554'],
#   ['HCP21_1555', 'HCP21_1556'],
#   ['HCP21_1557',
#    'HCP21_1558',
#    'HCP21_1558',
#    'HCP21_1559',
#    'HCP21_155_',
#    'HCP21_1560'],
#   ['HCP21_1561', 'HCP21_1563', 'HCP21_1564'],
#   ['HCP21_1565'],
#   ['HCP21_1566'],
#   ['HCP21_1567', 'HCP21_1568'],
#   ['HCP21_1569'],
#   ['HCP21_156_', 'HCP21_1570', 'HCP21_1571'],
#   ['HCP21_1572'],
#   ['HCP21_1572', 'HCP21_1573', 'HCP21_1574'],
#   ['HCP21_1575',
#    'HCP21_1576',
#    'HCP21_1576',
#    'HCP21_1577',
#    'HCP21_1578',
#    'HCP21_157_',
#    'HCP21_157_'],
#   ['HCP21_157_'],
#   ['HCP21_157_'],
#   ['HCP21_157_'],
#   ['HCP21_157_', 'HCP21_157_'],
#   ['HCP21_157_', 'HCP21_157_', 'HCP21_157_'],
#   ['HCP21_157_', 'HCP21_157_'],
#   ['HCP21_157_', 'HCP21_1580'],
#   ['HCP21_1581'],
#   ['HCP21_1583'],
#   ['HCP21_1584', 'HCP21_1584', 'HCP21_1585'],
#   ['HCP21_1586', 'HCP21_1587', 'HCP21_1588'],
#   ['HCP21_1589'],
#   ['HCP21_158_', 'HCP21_1590', 'HCP21_1591', 'HCP21_1592', 'HCP21_1593'],
#   ['HCP21_1594', 'HCP21_1595'],
#   ['HCP21_1596', 'HCP21_1597', 'HCP21_1597', 'HCP21_1598', 'HCP21_1599'],
#   ['HCP21_159_'],
#   ['HCP21_159_'],
#   ['HCP21_15__',
#    'HCP21_15__',
#    'HCP21_15__',
#    'HCP21_15__',
#    'HCP21_15__',
#    'HCP21_15__'],
#   ['HCP21_15__', 'HCP21_15__', 'HCP21_1600', 'HCP21_1601'],
#   ['HCP21_1602', 'HCP21_1603', 'HCP21_1603', 'HCP21_1604'],
#   ['HCP21_1606', 'HCP21_1607'],
#   ['HCP21_1608'],
#   ['HCP21_1609', 'HCP21_160_'],
#   ['HCP21_160_', 'HCP21_160_', 'HCP21_160_'],
#   ['HCP21_160_'],
#   ['HCP21_160_'],
#   ['HCP21_160_'],
#   ['HCP21_160_', 'HCP21_1610', 'HCP21_1611'],
#   ['HCP21_1612'],
#   ['HCP21_1613', 'HCP21_1614'],
#   ['HCP21_1614', 'HCP21_1615', 'HCP21_1616'],
#   ['HCP21_1617'],
#   ['HCP21_1618'],
#   ['HCP21_1618', 'HCP21_161_'],
#   ['HCP21_161_'],
#   ['HCP21_161_', 'HCP21_1620', 'HCP21_1621', 'HCP21_1622', 'HCP21_1623'],
#   ['HCP21_1624'],
#   ['HCP21_1624'],
#   ['HCP21_1625'],
#   ['HCP21_1626', 'HCP21_1626', 'HCP21_1627'],
#   ['HCP21_1628', 'HCP21_1628'],
#   ['HCP21_1629', 'HCP21_162_', 'HCP21_1630'],
#   ['HCP21_1631'],
#   ['HCP21_1632', 'HCP21_1633'],
#   ['HCP21_1633'],
#   ['HCP21_1634', 'HCP21_1635'],
#   ['HCP21_1637', 'HCP21_1638', 'HCP21_1639'],
#   ['HCP21_163_'],
#   ['HCP21_1640'],
#   ['HCP21_1640'],
#   ['HCP21_1641', 'HCP21_1642'],
#   ['HCP21_1643'],
#   ['HCP21_1644'],
#   ['HCP21_1645', 'HCP21_1645', 'HCP21_1646'],
#   ['HCP21_1647'],
#   ['HCP21_1648', 'HCP21_1649', 'HCP21_164_'],
#   ['HCP21_164_'],
#   ['HCP21_164_', 'HCP21_164_'],
#   ['HCP21_1650', 'HCP21_1651', 'HCP21_1652', 'HCP21_1653', 'HCP21_1654'],
#   ['HCP21_1655'],
#   ['HCP21_1656'],
#   ['HCP21_1656'],
#   ['HCP21_1657'],
#   ['HCP21_1658'],
#   ['HCP21_1659'],
#   ['HCP21_1659'],
#   ['HCP21_165_'],
#   ['HCP21_165_'],
#   ['HCP21_1660', 'HCP21_1661', 'HCP21_1663'],
#   ['HCP21_1664', 'HCP21_1665', 'HCP21_1666', 'HCP21_1667'],
#   ['HCP21_1668'],
#   ['HCP21_1669'],
#   ['HCP21_166_'],
#   ...])
